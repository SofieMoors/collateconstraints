# %%
from lxml import etree
from tqdm import tqdm
from collections import Counter
import pandas as pd

sigles = ['A', 'Ant', 'B', 'BR', 'C', 'D', 'D2', 'E', 'F', 'G', 'Ge', 'K', 'L', 'O', 'W', 'Y', 'Z']

# Create a dictionary to store word counts for each witness
word_counts_dict = {}

for sigle in tqdm(sigles):
    xml_file = f"../collateconstraints/data/xml_martijn/xml_{sigle}.xml"

    def extract_text_within_expan(element):
        text = ''
        for child in element.iter():
            if child.text:
                text += child.text.strip().lower()
            if child.tail:
                text += child.tail.strip().lower()
        return text.strip()

    tree = etree.parse(xml_file)
    NSMAP = {"tei": "http://www.tei-c.org/ns/1.0"}

    abbreviations = []

    for expan_element in tree.iterfind('.//tei:expan', namespaces=NSMAP):
        text_within_expan = extract_text_within_expan(expan_element)
        abbreviations.append(text_within_expan)

    #print(abbreviations)

    word_counts = Counter(abbreviations)
    word_counts_dict[sigle] = word_counts

# Create a DataFrame for each witness's top 5 results
dfs = []
for sigle, word_counts in word_counts_dict.items():
    top_results = word_counts.most_common(10)
    df = pd.DataFrame(top_results, columns=['Expanded Word', 'Count'])
    df['Witness'] = sigle
    dfs.append(df)

# Concatenate all DataFrames
result_df = pd.concat(dfs)

# Reset the index of the final DataFrame
result_df.reset_index(drop=True, inplace=True)

# Print the final DataFrame
print(result_df)
# Out:
# 100%|██████████████████████████████████████████| 17/17 [00:00<00:00, 143.13it/s]
#     Expanded Word  Count Witness
# 0            ende    289       A
# 1             hem     71       A
# 2            daer     68       A
# 3             van     66       A
# 4             den     59       A
# 5             men     30       A
# 6            omme     25       A
# 7            maer     25       A
# 8          sonder     24       A
# 9            want     21       A
# 10           ende      3     Ant
# 11            der      1     Ant
# 12         merten      1     Ant
# 13            dat      1     Ant
# 14        gelogen      1     Ant
# 15          neger      1     Ant
# 16        menegen      1     Ant
# 17     metterhant      1     Ant
# 18           lken      1     Ant
# 19           inne      1     Ant
# 20           ende    224       B
# 21            den     47       B
# 22            hem     46       B
# 23          minne     37       B
# 24         sonder     34       B
# 25            der     32       B
# 26            van     22       B
# 27         werelt     18       B
# 28           omme     18       B
# 29          bouen     16       B
# 30           ende     87      BR
# 31            dat     66      BR
# 32           niet     21      BR
# 33           daer     19      BR
# 34           sijn     13      BR
# 35          minne     13      BR
# 36           maer     12      BR
# 37            hem     12      BR
# 38         therte     11      BR
# 39         sonder     10      BR
# 40           ende    283       C
# 41            van      5       C
# 42     ghegronden      2       C
# 43          zinen      1       C
# 44          lamen      1       C
# 45          minen      1       C
# 46         smaken      1       C
# 47       ghenaken      1       C
# 48             in      1       C
# 49         steden      1       C
# 50           ende     12       D
# 51            van      7       D
# 52            den      5       D
# 53           geen      3       D
# 54        vrouwen      3       D
# 55           mijn      3       D
# 56        nyemant      3       D
# 57            ons      3       D
# 58         datmen      3       D
# 59         herten      2       D
# 60           ende     32      D2
# 61            van      7      D2
# 62        vrouwen      4      D2
# 63           mijn      4      D2
# 64            hem      4      D2
# 65          weder      3      D2
# 66         sonder      3      D2
# 67        mijnder      2      D2
# 68     nemmermeer      2      D2
# 69         eynden      1      D2
# 70           ende     40       E
# 71            dat     39       E
# 72           sijn     15       E
# 73           daer     15       E
# 74            hem     14       E
# 75            van     14       E
# 76          minne     10       E
# 77            men     10       E
# 78           want      9       E
# 79            een      8       E
# 80           ende    204       F
# 81           daer     22       F
# 82          minne     22       F
# 83            van     21       F
# 84         minnen     13       F
# 85         merten     11       F
# 86            den     11       F
# 87            hem     10       F
# 88           maer     10       F
# 89         sonder     10       F
# 90           ende    341       G
# 91            dat    217       G
# 92             in    111       G
# 93             en    109       G
# 94            den    103       G
# 95           niet     82       G
# 96            van     72       G
# 97           sijn     70       G
# 98           daer     62       G
# 99            hem     59       G
# 100          ende     17      Ge
# 101       vrouwen      7      Ge
# 102          daer      6      Ge
# 103           dat      4      Ge
# 104           den      4      Ge
# 105           van      3      Ge
# 106          niet      3      Ge
# 107           hem      3      Ge
# 108          waer      2      Ge
# 109        therte      2      Ge
# 110          ende     12       K
# 111           hem      4       K
# 112        sonder      3       K
# 113           den      3       K
# 114          niet      3       K
# 115        minnen      2       K
# 116       maertin      2       K
# 117           der      2       K
# 118           mer      2       K
# 119         weder      1       K
# 120          ende     80       L
# 121          daer     30       L
# 122           dat     22       L
# 123           hem     17       L
# 124           den     15       L
# 125          omme     13       L
# 126           van     13       L
# 127       vrouwen     11       L
# 128          haer      9       L
# 129           men      8       L
# 130          ende    128       O
# 131           van     28       O
# 132           hem     25       O
# 133           den     24       O
# 134         minne     24       O
# 135          omme     18       O
# 136          zijn     16       O
# 137        minnen     15       O
# 138           men     11       O
# 139        zonder      8       O
# 140          ende    102       W
# 141            in     27       W
# 142           dat     22       W
# 143            en     20       W
# 144           van     17       W
# 145          niet     15       W
# 146           hem     14       W
# 147          sijn     14       W
# 148           den     13       W
# 149          daer     11       W
# 150          ende     35       Y
# 151           dat     10       Y
# 152          daer      8       Y
# 153           den      5       Y
# 154        heeren      4       Y
# 155           men      4       Y
# 156        sonder      3       Y
# 157     verclaren      3       Y
# 158          haer      3       Y
# 159           van      3       Y
# 160          ende     83       Z
# 161           dat     53       Z
# 162           een     23       Z
# 163          haer     18       Z
# 164          niet     18       Z
# 165           den     17       Z
# 166           hem     17       Z
# 167           met     16       Z
# 168          daer     16       Z
# 169          sijn     16       Z

# %%
from lxml import etree
from tqdm import tqdm
from collections import Counter
import pandas as pd

sigles = ['A', 'Ant', 'B', 'BR', 'C', 'D', 'D2', 'E', 'F', 'G', 'Ge', 'K', 'L', 'O', 'W', 'Y', 'Z']

# Create a dictionary to store word counts for each witness
word_counts_dict = {}

for sigle in tqdm(sigles):
    xml_file = f"../collateconstraints/data/xml_martijn/xml_{sigle}.xml"

    def extract_text_within_expan(element):
        text = ''
        for child in element.iter():
            
            if 'g' and 'ref' in child.attrib and child.attrib['ref'] == '#bar':
                text += u'\u0304'
            elif 'g' and 'ref' in child.attrib and child.attrib['ref'] == '#apomod': 
                text += u'\u02bc'    
            elif 'g' and 'ref' in child.attrib and child.attrib['ref'] == '#usmod': 
                text += u'\ua770'     
            elif 'g' and 'ref' in child.attrib and child.attrib['ref'] == '#condes': 
                text += u'\ua76f'  
            elif 'g' and 'ref' in child.attrib and child.attrib['ref'] == '#para':
                text += u'\xb6'
            elif 'g' and 'ref' in child.attrib and child.attrib['ref'] == '#etfin': 
                text += u'\ua76b'
            elif 'g' and 'ref' in child.attrib and child.attrib['ref'] == '#pbardes': 
                text += u'\ua751'
            elif 'g' and 'ref' in child.attrib and child.attrib['ref'] == '#pflour': 
                text += u'\ua753'
            else:
                if child.attrib == '#ref':
                    text += str(child.attrib)
           
            superscript_dict = {'a':'ᵃ', 'b':'ᵇ', 'c':'ᶜ', 'd':'ᵈ', 'e':'ᵉ', 'f':'ᶠ',
                               'g':'ᵍ', 'h':'ʰ', 'i':'ᶦ', 'j':'ʲ', 'k':'ᵏ', 'l':'ˡ', 
                                'm':'ᵐ', 'n':'ⁿ', 'o':'ᵒ', 'p':'ᵖ', 'r':'ʳ', 's':'ˢ', 
                                't':'ᵗ', 'u':'ᵘ', 'v':'ᵛ', 'w':'ʷ', 'x':'ˣ', 'y': 'ʸ', 'z': 'ᶻ'}
            
            if 'hi' and 'rend' in child.attrib and child.attrib['rend'] == 'superscript': 
                if child.text in superscript_dict:
                    text += str(superscript_dict[child.text]).strip()
                    
            elif child.text:
                text += child.text.strip().lower()
    
            if child.tail:
                text += child.tail.strip().lower()
                 
        return text.strip()

    tree = etree.parse(xml_file)
    NSMAP = {"tei": "http://www.tei-c.org/ns/1.0"}

    abbreviations = []

    for expan_element in tree.iterfind('.//tei:abbr', namespaces=NSMAP):
        text_within_expan = extract_text_within_expan(expan_element)
        abbreviations.append(text_within_expan)
   
    print(abbreviations)

    word_counts = Counter(abbreviations)
    word_counts_dict[sigle] = word_counts

# Create a DataFrame for each witness's top 5 results
dfs = []
for sigle, word_counts in word_counts_dict.items():
    top_results = word_counts.most_common(10)
    df = pd.DataFrame(top_results, columns=['Expanded Word', 'Count'])
    df['Witness'] = sigle
    dfs.append(df)

# Concatenate all DataFrames
result_df = pd.concat(dfs)

# Reset the index of the final DataFrame
result_df.reset_index(drop=True, inplace=True)

# Print the final DataFrame
print(result_df)
# Out:
# 100%|██████████████████████████████████████████| 17/17 [00:00<00:00, 121.98it/s]
# ['mʼtin', 'wʼelt', 'lāghe', 'staē', 'cranckē', 'vᵒuwe', 'vʼeere', 'sondʼ', 'heʼen', 'dē', 'valschē', 'heʼen', 'conē', 'en̄', 'pluckē', 'vandē', 'en̄', 'dē', 'rechtē', 'bespottē', 'en̄', 'vʼscroue', 'ghedoghē', 'en̄', 'en̄', 'hē', 'indē', 'helschē', 'sondʼ', 'ouʼ', 'sprekē', 'ondʼ', 'wanē', 'quā', 'wilē', 'en̄', 'en̄', 'indē', 'en̄', 'ꝯpaen', 'hebbē', 'vʼstaē', 'dʼ', 'vʼclaerne', 'dinē', 'beuaē', 'vʼmochte', 'dē', 'hemelschē', 'traē', 'en̄', 'en̄', 'wʼelt', 'vʼheffene', 'bouē', 'vʼuwe', 'en̄', 'en̄', 'en̄', 'heʼen', 'en̄', 'gheuē', 'eenē', 'en̄', 'willē', 'wanē', 'ōme', 'en̄', 'dē', 'scalckē', 'radē', 'en̄', 'sceldē', 'dē', 'heʼe', 'wordē', 'clēmene', 'ōmaer', 'en̄', 'wʼelt', 'en̄', 'en̄', 'vʼbannē', 'en̄', 'wedʼ', 'bidʼ', 'sonnē', 'aldʼ', 'wʼelt', 'oghē', 'dʼ', 'ieghē', 'ghetoghē', 'hʼ', 'vʼdonckert', 'hē', 'en̄', 'vʼplecht', 'dē', 'droeghē', 'ouʼ', 'en̄', 'en̄', 'hē', 'en̄', 'dʼ', 'ōme', 'wāt', 'dʼ', 'wanē', 'comē', 'wordē', 'wāt', 'hʼ', 'vā', 'dʼmē', 'hē', 'dē', 'langhē', 'wē', 'wāt', 'en̄', 'en̄', 'brieuē', 'ghewaghē', 'heʼen', 'gheuē', 'bescreuē', 'dā', 'vorē', 'heʼe', 'sneuē', 'en̄', 'vʼdreuē', 'heʼen', 'en̄', 'segghē', 'ouʼ', 'dē', 'heʼen', 'doemē', 'dē', 'indē', 'scalkē', 'dā', 'dē', 'ouʼ', 'eenē', 'beuolē', 'en̄', 'blendʼ', 'vʼkeert', 'vʼdort', 'dauēture', 'vā', 'en̄', 'dē', 'hʼte', 'papē', 'sullēt', 'vʼbrant', 'en̄', 'vʼsmort', 'mē', 'dusdanē', 'sakē', 'ghenakē', 'butē', 'hoedē', 'en̄', 'godlikē', 'dā', 'en̄', 'mēne', 'dē', 'vroedē', 'hellē', 'mē', 'gheē', 'mesdoē', 'en̄', 'mē', 'ēmer', 'en̄', 'dā', 'hē', 'en̄', 'mē', 'gheenē', 'vʼtaert', 'wāt', 'hʼ', 'pandē', 'vā', 'harē', 'pondē', 'ghegrondē', 'en̄', 'en̄', 'vā', 'dē', 'quadē', 'hʼte', 'wʼdes', 'vʼseert', 'gheenē', 'dā', 'vʼtert', 'en̄', 'en̄', 'en̄', 'ghebondē', 'en̄', 'sondē', 'dē', 'en̄', 'langhʼ', 'sondē', 'dā', 'slaghē', 'vʼsceet', 'hertē', 'dē', 'hertē', 'om̄e', 'leuē', 'en̄', 'hellē', 'dʼ', 'hʼte', 'en̄', 'en̄', 'en̄', 'vʼstane', 'hē', 'en̄', 'en̄', 'hē', 'zwʼ', 'en̄', 'hē', 'wrakē', 'pleghē', 'ōme', 'mē', 'en̄', 'en̄', 'sondē', 'en̄', 'makē', 'dē', 'en̄', 'warē', 'hellē', 'soudē', 'houdē', 'en̄', 'scrifturē', 'en̄', 'leekē', 'liedē', 'dinghē', 'vʼstaet', 'dā', 'wondē', 'naeyē', 'hondē', 'en̄', 'tallē', 'stondē', 'vvanē', 'ghegrondē', 'saē', 'dʼ', 'iaghē', 'en̄', 'vaē', 'willē', 'en̄', 'vraghē', 'gaē', 'wāt', 'ghedaē', 'dommē', 'en̄', 'dā', 'ieghē', 'en̄', 'berechtē', 'dʼ', 'eenē', 'onwerdē', 'werpē', 'sondʼ', 'vā', 'dadē', 'vā', 'gradē', 'vā', 'mē', 'hē', 'seluē', 'wesē', 'gherechtichedē', 'en̄', 'vā', 'vandē', 'onbesceedē', 'ghenesē', 'bē', 'en̄', 'vʼgheten', 'hē', 'begaē', 'gheldē', 'en̄', 'redenē', 'en̄', 'vordē', 'helschē', 'werdē', 'vʼbeten', 'en̄', 'mīne', 'en̄', 'vraghē', 'proeftmē', 'sondeʼ', 'en̄', 'dandʼ', 'wʼelt', 'hʼ', 'naturē', 'volghē', 'hʼ', 'indʼ', 'maghedē', 'iodē', 'bringhē', 'indʼ', 'dā', 'hē', 'seluē', 'dʼ', 'en̄', 'en̄', 'minnē', 'hē', 'mē', 'vʼblenden', 'indʼ', 'hellē', 'dʼ', 'ellendē', 'mʼ', 'dē', 'rikē', 'gheenē', 'gheenē', 'nēmermeer', 'dʼ', 'mē', 'hʼ', 'en̄', 'dandʼ', 'wāt', 'en̄', 'mīne', 'dickē', 'wesē', 'vʼwoet', 'wāt', 'vʼslijt', 'en̄', 'en̄', 'hē', 'sinē', 'hē', 'dorstē', 'ondʼsceet', 'vā', 'hē', 'eʼe', 'omdē', 'hebbē', 'ōme', 'hē', 'en̄', 'en̄', 'mē', 'ondʼ', 'gloriē', 'dʼ', 'ōme', 'wāt', 'smeltē', 'dʼ', 'hʼte', 'ōme', 'vā', 'en̄', 'hʼtē', 'tōghe', 'oghē', 'onwerdē', 'en̄', 'meneghē', 'en̄', 'wilē', 'en̄', 'en̄', 'en̄', 'mʼ', 'nēmermee', 'werdē', 'hē', 'vā', 'dʼ', 'inghelē', 'beuē', 'scuwē', 'dʼ', 'bescreuē', 'bleuē', 'en̄', 'mē', 'wʼelt', 'wāt', 'vʼblijt', 'nēmermeer', 'vʼslijt', 'mē', 'bescreuē', 'hertē', 'hē', 'vʼspanen', 'conē', 'minnē', 'rollē', 'trouwē', 'mē', 'heʼen', 'en̄', 'vrouwē', 'en̄', 'minnē', 'vʼplecht', 'en̄', 'en̄', 'mē', 'bescauwē', 'wʼelt', 'iegh ...
# ['en̄', 'dʼ', 'en̄', 'mertē', 'dꝫ', 'gelogē', 'negʼ', 'menegē', 'en̄', 'metterhāt', 'lkē', 'īne']
# ['gaē', 'weʼlt', 'cranckē', 'zaē', 'sondʼ', 'en̄', 'connē', 'dʼstaen', 'plockē', 'vandē', 'en̄', 'en̄', 'vʼscoue', 'en̄', 'indē', 'helschē', 'sondʼ', 'ondʼ', 'wanē', 'en̄', 'antwʼt', 'indē', 'en̄', 'sprekē', 'cōpaen', 'hebbē', 'vʼstaen', 'vʼclarē', 'dinē', 'vʼmochte', 'hemelschē', 'zinnē', 'vʼheffen', 'bouē', 'en̄', 'dē', 'en̄', 'herē', 'gheuē', 'dʼ', 'enē', 'tclemmē', 'ōmaer', 'vʼbannē', 'bidʼ', 'sonnē', 'dʼ', 'weʼlt', 'scoonhᵗ', 'vʼdonckert', 'creaturē', 'zurē', 'scalkē', 'droughē', 'ouʼ', 'en̄', 'en̄', 'en̄', 'dʼ', 'ōme', 'wanē', 'comē', 'gheē', 'dairmē', 'dē', 'langē', 'en̄', 'en̄', 'brieuē', 'ghewaghē', 'lantsherē', 'gheuē', 'bescreuē', 'broschʼ', 'bleuē', 'lantsheʼ', 'hē', 'sneuē', 'vʼdreuē', 'heʼn', 'wetʼ', 'ouʼ', 'vʼsmale', 'heʼn', 'indē', 'creaturē', 'vʼlies', 'dʼ', 'naturē', 'en̄', 'blindʼ', 'vʼkeert', 'telkʼ', 'vʼdort', 'en̄', 'makē', 'hʼte', 'vʼt', 'wʼtstu', 'vʼbrant', 'vʼsmoirt', 'nᵗ', 'sakē', 'genakē', 'butē', 'en̄', 'godlikē', 'en̄', 'mē', 'hē', 'vroedē', 'indʼ', 'ondʼ', 'duuelē', 'tʼ', 'hellē', 'mē', 'emmʼ', 'vʼzwairt', 'ghebondē', 'alsmē', 'ghenē', 'stondē', 'vʼtairt', 'nyemē', 'ghegrondē', 'dē', 'quadē', 'hʼte', 'wʼdets', 'vʼzeert', 'ghenē', 'vʼteert', 'en̄', 'en̄', 'ghindʼ', 'wʼt', 'en̄', 'ghebondē', 'en̄', 'kindeʼn', 'enē', 'sondē', 'en̄', 'sondē', 'langhʼ', 'tormentē', 'slaghē', 'sondʼ', 'vʼsceet', 'hertē', 'dē', 'tormēt', 'nadʼ', 'hʼtē', 'leuē', 'nēmermeer', 'hʼte', 'en̄', 'en̄', 'vʼstaen', 'louerē', 'en̄', 'hē', 'ōmaer', 'en̄', 'hē', 'wrakē', 'ōme', 'mē', 'en̄', 'en̄', 'sondē', 'en̄', 'dē', 'en̄', 'warē', 'soudē', 'dattʼ', 'comē', 'en̄', 'wanēse', 'ghegrondē', 'lekē', 'liedē', 'dinghē', 'vʼstaen', 'wondē', 'vandē', 'hondē', 'en̄', 'stondē', 'wanē', 'gegᵒndē', 'wortelē', 'samē', 'dōmē', 'dē', 'ionxtē', 'en̄', 'berechtē', 'wʼpen', 'sondʼ', 'gradē', 'en̄', 'datmē', 'scadē', 'seluē', 'en̄', 'en̄', 'vʼgheten', 'gheldē', 'nēmer', 'wetē', 'en̄', 'hēne', 'en̄', 'wʼdē', 'vʼbeten', 'ionxtē', 'ghesletē', 'parlemēt', 'wijshᵗ', 'mīne', 'tormēt', 'mīne', 'vā', 'prouftmē', 'sondʼ', 'en̄', 'dandʼ', 'mīne', 'naturē', 'mīne', 'nedʼ', 'indʼ', 'ondʼ', 'dʼ', 'bringhē', 'vʼuairde', 'seluē', 'dʼ', 'mīē', 'en̄', 'mīne', 'mīne', 'vʼblendē', 'indʼ', 'ellendē', 'dē', 'rikē', 'ghenē', 'ghenē', 'nēmer', 'vremdē', 'eyndē', 'sceyndē', 'dandʼ', 'mīne', 'nadʼ', 'weʼlt', 'mīne', 'dickē', 'riddʼscap', 'vʼwoet', 'dē', 'woukʼ', 'riddeʼ', 'vʼsleet', 'en̄', 'dandʼ', 'hē', 'sinē', 'dorstē', 'mīne', 'ondʼsceet', 'ōme', 'dē', 'hebbē', 'hē', 'en̄', 'en̄', 'ōme', 'datmē', 'ondʼ', 'dʼ', 'gloriē', 'ōme', 'mīne', 'hʼte', 'ōmeghinc', 'reynē', 'en̄', 'ondʼ', 'goedē', 'onwerdē', 'en̄', 'meneghē', 'en̄', 'wilē', 'en̄', 'nuttē', 'leuē', 'mīne', 'nēmermeer', 'zij̄', 'hē', 'gheuē', 'mīne', 'leuē', 'dʼ', 'heʼn', 'bescreuē', 'bleuē', 'diemē', 'tʼ', 'vʼblijt', 'nēmermeer', 'vʼslijt', 'alsmē', 'bescreuē', 'hartē', 'gadʼ', 'enē', 'reynē', 'hē', 'connē', 'mīnē', 'twīt', 'mʼ', 'alsmē', 'mīne', 'mīnē', 'vʼplecht', 'mē', 'weʼlt', 'dʼ', 'mīnē', 'en̄', 'bedauwē', 'achtʼ', 'mauwē', 'vʼdraecht', 'en̄', 'vʼmaghet', 'wʼde', 'comē', 'vandē', 'dandʼ', 'quamē', 'seitmē', 'dʼ', 'weʼlt', 'comē', 'vʼgrame', 'dē', 'dē', 'liedē', 'sondʼ', 'ondʼ', 'vandē', 'liedē', 'maectʼ', 'vandē', 'quadē', 'vʼmoirde', 'vʼdomt', 'redenē', 'anschij̄', 'hʼten', 'vādē', 'qᵃdē', 'vadʼ', 'hē', 'mesquā', 'vintmē', 'vandē', 'vʼnam', 'hē', 'vʼtelt', 'onrechtʼ', 'comē', 'pʼnche', 'datmē', 'vʼdomē', 'vʼcopen', 'datmē', 'harē', 'rechtē', 'mʼ', 'en̄', 'onvromē', 'ōnerē', 'hē', 'ōme', 'neidʼ', 'andʼ', 'sinē', 'weʼlt', 'sinē', 'zij̄', 'vʼsmaet', 'en̄', 'dʼ', 'rechtʼ', 'vʼcochtene', 'enē', 'niemē', 'hē', 'gherouē', 'clemmē', 'pointē', 'lerē', 'mīne', 'pointē', 'en̄', 'puntē', 'dinckē', 'sondʼ', 'vʼkerē', 'trauwē', 'vʼstaen', 'dinē', 'woirdē', 'gherechtʼ', 'boekē', ...
# ['mouwē', 'en̄', 'dꝫ', 'vʼmaecht', 'dꝫ', 'wʼde', 'dꝫ', 'comē', 'dandʼ', 'dʼbi', 'dorꝑ', 'dꝫ', 'dʼ', 'en̄', 'ꝑsemir', 'sondʼ', 'ondʼ', 'sij̄', 'wʼ', 'claertē', 'vandē', 'liedē', 'dꝫ', 'winnē', 'en̄', 'dꝫ', 'eyghij̄', 'vandē', 'quadē', 'vʼdoemt', 'sij̄', 'nꝫ', 'fij̄', 'dꝫ', 'mʼ', 'dorꝑlijc', 'dꝫ', 'dꝫ', 'vandē', 'quadē', 'vadʼ', 'dꝫ', 'dꝫ', 'hē', 'quā', 'tfadʼs', 'dꝫ', 'vʼna', 'dꝫ', 'en̄', 'vʼtelt', 'dꝫ', 'dꝫmen', 'en̄', 'dꝫmen', 'eygē', 'en̄', 'noemē', 'rechtē', 'en̄', 'en̄', 'hē', 'dꝫ', 'ondʼgaet', 'en̄', 'dꝫ', 'en̄', 'mʼ', 'dꝫ', 'vʼsmaet', 'en̄', 'dʼ', 'en̄', 'en̄', 'dʼ', 'vʼcochtmen', 'sulkē', 'hē', 'dꝫ', 'hʼten', 'mertē', 'clemmē', 'poentē', 'mīne', 'nꝫ', 'nꝫ', 'en̄', 'dunckē', 'en̄', 'vʼstaen', 'gaē', 'dꝫ', 'sondʼ', 'machmē', 'dwaē', 'gedaē', 'traē', 'dorꝑs', 'nꝫ', 'ontfaē', 'dꝫ', 'dʼ', 'dꝫ', 'vʼmoert', 'en̄', 'en̄', 'en̄', 'ghʼne', 'en̄', 'ondʼuonde', 'tē', 'en̄', 'aldʼ', 'sij̄', 'dʼ', 'dʼ', 'nēmermeer', 'en̄', 'en̄', 'en̄', 'dꝫ', 'sij̄', 'mij̄', 'en̄', 'vʼdriuen', 'en̄', 'fij̄', 'wʼ', 'eyghij̄', 'wʼ', 'en̄', 'en̄', 'ontliuē', 'dꝫ', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'vʼwoet', 'dꝫ', 'stortmē', 'smenschē', 'en̄', 'vʼstaen', 'dꝫ', 'sondʼ', 'lietmē', 'en̄', 'dwaē', 'en̄', 'hʼ', 'gedaē', 'en̄', 'vandē', 'wʼt', 'minnē', 'dʼ', 'hertē', 'en̄', 'hʼte', 'dij̄', 'dꝫ', 'mīnen', 'en̄', 'dꝫ', 'hulpē', 'geē', 'hē', 'dꝫ', 'swʼ', 'en̄', 'thʼte', 'thʼte', 'vʼwijt', 'nꝫ', 'vʼmijt', 'ēmer', 'dʼ', 'dꝫ', 'menigē', 'en̄', 'dꝫ', 'wʼ', 'en̄', 'en̄', 'en̄', 'en̄', 'sulkē', 'dꝫ', 'dꝫ', 'dꝫ', 'tuwʼt', 'dʼna', 'smenschē', 'sij̄', 'sondʼ', 'en̄', 'en̄', 'en̄', 'nꝫ', 'wʼt', 'mʼ', 'dꝫ', 'dꝫ', 'en̄', 'hʼden', 'vʼtelt', 'dʼ', 'thʼte', 'en̄', 'harē', 'mʼ', 'dꝫ', 'thʼte', 'hʼ', 'wedʼ', 'thʼte', 'thʼte', 'dꝫ', 'nꝫ', 'dʼ', 'mʼ', 'pliē', 'desē', 'diē', 'hē', 'pogē', 'sij̄', 'gesciē', 'en̄', 'ghenē', 'nꝫ', 'mʼ', 'hʼte', 'en̄', 'wʼt', 'wʼheit', 'sꝑt', 'dʼ', 'hertē', 'dꝫ', 'wʼt', 'en̄', 'hʼ', 'wondē', 'gindʼwaert', 'dꝫ', 'en̄', 'vʼloeste', 'thʼte', 'vʼswaert', 'hʼ', 'smakē', 'tswʼt', 'dꝫ', 'thʼte', 'mʼ', 'dꝫ', 'en̄', 'sondʼ', 'en̄', 'derwʼt', 'sij̄', 'gehingē', 'dꝫ', 'gehulpē', 'hʼte', 'nꝫ', 'bedwingē', 'dꝫ', 'en̄', 'hʼs', 'vadʼ', 'en̄', 'hʼ', 'en̄', 'hʼ', 'rechtē', 'mʼ', 'thʼte', 'hʼ', 'dʼ', 'sondʼ', 'mꝫ', 'dꝫ', 'thʼte', 'en̄', 'geē', 'nꝫ', 'dꝫ', 'sondʼ', 'en̄', 'dij̄', 'wʼ', 'wʼt', 'sij̄', 'sʼ', 'en̄', 'cā', 'ontbindē', 'alexandʼ', 'swʼt', 'nꝫ', 'hē', 'bewindē', 'dinē', 'diedē', 'vlaendʼlant', 'vʼblinden', 'mꝫ', 'fauelē', 'en̄', 'en̄', 'vʼsmoort', 'en̄', 'mꝫ', 'mīne', 'nꝫ', 'vʼdoort', 'mꝫ', 'en̄', 'en̄', 'vā', 'mīnen', 'mīne', 'mindē', 'en̄', 'dꝫ', 'dʼ', 'vrouwē', 'sarē', 'vʼheffen', 'dʼ', 'redenē', 'vʼwan', 'en̄', 'cā', 'sondʼ', 'bescouwē', 'mīners', 'genietē', 'makē', 'mīne', 'mīners', 'blouwē', 'minē', 'dʼ', 'mī', 'en̄', 'en̄', 'dꝫ', 'hʼ', 'en̄', 'wʼt', 'hʼ', 'mīnen', 'eldʼ', 'en̄', 'nꝫ', 'mīne', 'vʼwan', 'hē', 'dꝫ', 'hē', 'mꝫ', 'vʼuacht', 'hē', 'sampsoē', 'mīnen', 'dʼ', 'doē', 'sij̄', 'vrouwē', 'mīne', 'spoē', 'nꝫ', 'sij̄', 'ontdoē', 'en̄', 'hē', 'ontfloē', 'ontsinnē', 'hʼ', 'vʼwinnen', 'nꝫ', 'dꝫ', 'mīne', 'dꝫ', 'dʼinne', 'dꝫ', 'ghemoetē', 'en̄', 'mij̄', 'mīne', 'en̄', 'minē', 'swʼt', 'thʼte', 'nēmermeer', 'dꝫtu', 'en̄', 'hʼte', 'dꝫ', 'vʼsmoorde', 'liedē', 'nꝫ', 'dē', 'gesciē', 'nꝫ', 'tiē', 'mʼ', 'dʼ', 'sondē', 'vliē', 'en̄', 'mīne', 'swʼt', 'dꝫ', 'mꝫ', 'ꝑtien', 'vʼstant', 'mīne', 'vāt', 'mīne', 'dꝫ', 'sij̄', 'hʼten', 'nꝫ', 'dꝫ', 'coninghē', 'dʼ', 'wʼ', 'wʼ', 'dꝫ', 'dꝫ', 'mꝫ', 'hʼten', 'mʼ', 'en̄', 'en̄', 'houerdē', 'nēmermeer', 'wʼt', 'redenē', 'dꝫ', 'leuē', 'hē', 'mꝫ', 'minē', 'wʼ', 'sneuē', 'hʼ', 'en̄', 'mꝫ', 'sij̄', 'dꝫ', 'mīne', 'wedʼstoot', 'dʼ', 'dʼ', 'sinē', 'mij̄', 'mʼ', 'hʼ', 'vʼwonnen', 'mīne', 'en̄', 'dʼ', 'en̄', 'mij̄', 'ōmaer', 'dꝫ', 'dʼ', 'dʼ', 'nꝫ', 'hʼ', 'mꝫ', 'wondē', 'mꝫten', 'dꝫ', 'en̄', 'hē', 'becliuē', 'mij̄', 'selē', 'keytiuē', 'dʼ', 'ontliuē', 'ondʼlinge', 'en̄', 'dꝫ', 'hʼte', 'dʼtoe', 'kinnē', 'v ...
# ['en̄', 'en̄', 'en̄', 'zinē', 'en̄', 'en̄', 'lamē', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'minē', 'en̄', 'smakē', 'ghenakē', 'en̄', 'en̄', 'ī', 'en̄', 'en̄', 'stedē', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'vā', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'vā', 'en̄', 'en̄', 'en̄', 'en̄', 'vernomē', 'en̄', 'en̄', 'en̄', 'blomē', 'vʼraden', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'vā', 'dē', 'reinē', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'ghegrondē', 'en̄', 'en̄', 'clīme', 'en̄', 'wāt', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'vā', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'amē', 'am̄.', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'ghegrondē', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'vā', 'en̄', 'en̄', 'tesamē', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'quadē', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'mannē', 'en̄']
# ['gaē', 'hemelschē', 'dā', 'neē', 'geē', 'weē/', 'hertē', 'hellē', 'cōt', 'niemāt', 'vʼseert', 'sondē', 'wrakē', 'makē', 'vʼstaet', 'eē', 'wanē', 'gegrōdē', 'staē/', 'berechtē', 'gheldē', 'parlemēt', 'werdē', 'tsamē', 'connē', 'ghescouwē', 'vādē', 'wāt', 'vernā', 'scherē.', 'nꝫ', 'dꝫ', 'keerē:', 'afdwaē', 'wij̄.', 'ghedaē', 'menighē', 'brāt', 'smenschē', 'mettē', 'minnē', 'eertschē', 'en̄', 'blēt', 'willēs', 'vrouwē', 'vrouwē', 'dꝫ', 'mānē', 'pliē', 'schoenhꝫ', 'spiē.', 'dē', 'makē', 'vrouwē', 'vʼblint', 'lā.', 'dij̄', 'geē', 'sprekē', 'dūckes', 'verdorē', 'versmorē', 'stedē', 'vā', 'coē', 'ontuloē', 'diemē', 'vragēs', 'wondē', 'en̄', 'eē', 'bāt', 'mꝫ', 'zij̄re', 'hāt', 'en̄', 'testamēt', 'conuēt', 'cā', 'dē', 'en̄', 'mij̄', 'vā', 'nyemāt', 'leuē', 'minnē', 'ghebleuē', 'mynē', 'ghenē', 'sneuē/', 'diēste', 'diēs', 'ōs', 'datmē', 'ōs', 'legghē', 'mij̄', 'mij̄', 'ōmaer', 'onderuōden', 'ōs', 'brenghē', 'mīme', 'eȳdet', 'en̄', 'lestē', 'stondē.', 'vryē', 'wōdē:', 'mānē', 'mettē', 'sinē', 'bouē', 'enghelē', 'roekē', 'vā', 'doekē/', 'soudʼ', 'vloekē', 'namē', 'yngelē', 'quamē/', 'mīne', 'ghewerckē', 'daermē', 'kēt', 'en̄', 'troēs', 'merckē', 'versterckē', 'segghē', 'clerckē', 'swerckē', 'beclagē', 'hē', 'rustē', 'iaghē', 'dagē', 'plagē', 'vlaghē/', 'cleynē/', 'verclenē.', 'versteenē', 'loochēt', 'beweenē', 'ongheborē:', 'horē.', 'dē', 'heylighē', 'leerē', 'dē', 'dorē', 'ghesworē', 'vadʼs', 'en̄', 'orcōde.', 'vandē', 'heilighē', 'ontbōde', 'vōde.', 'nyemāt', 'makē.', 'wāt', 'mogē', 'genakē', 'en̄', 'cōnē', 'gherakē/', 'wakē', 'tē', 'gheē', 'scherē', 'minderē', 'meerē/', 'ghenerē', 'niemāt', 'verterē', 'vʼuolt', 'kerē', 'geē', 'doē', 'ghisterē', 'alsmē', 'vā', 'bescreuē', 'ghebleuē:', 'gheē', 'aē', 'cleuē/', 'verheuē', 'beneuē', 'bescreuē:', 'haddē', 'mīne', 'ghewīne', 'coninghīne/', 'vā', 'mariē', 'sinnē', 'houaerdiē', 'becochtē', 'hē', 'ghecomē', 'beromē/', 'bloomē/', 'dē', 'mā', 'verradē', 'gheladē', 'datmē', 'en̄', 'vā', 'reynē', 'scarē', 'nyemāt', 'cāt', 'gegrōdē', 'climmē', 'en̄', 'winnē', 'en̄', 'dāck', 'vā', 'verclarē', 'warē', 'en̄', 'hertē', 'datmē', 'indē', 'brāt']
# ['vrouwē', 'en̄', 'eyndē', 'en̄', 'dʼ', 'geē', 'en̄', 'vā', 'wedʼ', 'en̄', 'eū', 'vā', 'steden/borgē/bosscē', 'en̄', 'en̄', 'ontbendē', 'sondʼ', 'mij̄s', 'andʼ', 'diemē', 'vrouwē', 'mij̄', 'hē', 'mijndʼ', 'hertē', 'en̄', 'en̄', 'quamē', 'latē', 'smakē', 'ʼ', 'en̄', 'en̄', 'en̄', 'en̄', 'sondʼ', 'en̄', 'en̄', 'en̄', 'en̄', 'hē', 'vʼsmoort', 'vā', 'en̄', 'heydenē', 'vʼheffen', 'begā', 'vrouwē', 'vʼwan', 'en̄', 'en̄', 'en̄', 'en̄', 'vā', 'mij̄der', 'en̄', 'en̄', 'vā', 'bekennē', 'vrouwē', 'minnē', 'ghemoetē', 'en̄', 'mij̄', 'en̄', 'nēmermeer', 'eenē', 'en̄', 'mij̄', 'grāmarijen', 'dē', 'exemplē', 'sondʼ', 'en̄', 'en̄', 'en̄', 'vā', 'vā', 'ongheteldē', 'hē', 'en̄', 'en̄', 'nēmermeer', 'hē', 'mlinnē', 'minē', 'wedʼ', 'gheuē', 'leuē', 'en̄', 'wedʼ', 'mij̄']
# ['wāt', 'rʼ', 'vʼslit', 'en̄', 'dꝫ', 'sij̄', 'dandʼ', 'waʼe', 'en̄', 'hē', 'indē', 'hē', 'dorstē', 'mīne', 'ondʼsceet', 'vā', 'hē', 'en̄', 'pinē', 'omdē', 'hebbē', 'dꝫ', 'dꝫ', 'hē', 'en̄', 'en̄', 'ō', 'dogꝫ', 'dꝫ', 'nꝫ', 'ondʼ', 'ydeldʼ', 'gloriē', 'daʼ', 'mꝫ', 'ōme', 'wāt', 'haʼe', 'smeltē', 'hebbē', 'daʼ', 'hʼte', 'mꝫ', 'ōme', 'wꝰ', 'vā', 'reynē', 'dij̄re', 'hʼten', 'loddʼs', 'tōghe', 'wꝰ', 'wʼt', 'eēdʼ', 'oghēwinc', 'ondʼ', 'wʼde', 'onwʼdeghē', 'en̄', 'ōtsprīc', 'meneghē', 'en̄', 'wilē', 'en̄', 'dꝫ', 'weldoē', 'hebbē', 'en̄', 'en̄', 'erē', 'nuttē', 'eē', 'leuē', 'mʼ', 'mīne', 'eē', 'dꝫ', 'nēmermeer', 'wʼdē', 'mēt', 'haʼ', 'gheuē', 'mīne', 'vā', 'ī', 'daʼ', 'inglē', 'scuwē', 'dʼ', 'erē', 'wāt', 'salomoē', 'bescreuē', 'nꝫ', 'mīne', 'dē', 'ontbꝫ', 'dꝫs', 'dꝫ', 'haʼ', 'diemē', 'tʼ', 'weʼlt', 'wāt', 'taldʼ', 'vʼblijt', 'en̄', 'mē', 'tʼuwe', 'maʼe', 'aldꝰ', 'sij̄', 'vʼslijt', 'haʼ', 'nēmermeer', 'mʼ', 'sij̄', 'sīne', 'en̄', 'gheē', 'mīne', 'alsmē', 'bescreuē', 'hʼtē', 'tsamē', 'enē', 'reynē', 'mīne', 'dꝫ', 'dꝫti', 'hē', 'vʼspanen', 'cōnē', 'mīnē', 'nꝫ', 'eē', 'twīt', 'sij̄', 'rollē', 'butē', 'mē', 'mīners', 'ī', 'trouwē', 'alsmē', 'zwʼter', 'zwanē', 'dꝰ', 'mīne', 'planē', 'mertē', 'segghē', 'hʼen', 'en̄', 'vʼuwen', 'en̄', 'en̄', 'ī', 'dꝫ', 'mꝫ', 'mīnē', 'sij̄', 'vʼplecht', 'en̄', 'mē', 'caēt', 'weʼlt', 'ieghē', 'dʼ', 'reyndʼ', 'mīnē', 'en̄', 'volghē', 'ontrouwē', 'en̄', 'zʼe', 'vʼdouwē', 'mʼ', 'achtʼ', 'makē', 'mouwē', 'antwʼt', 'en̄', 'vʼdraegt', 'mʼten', 'waēdi', 'dꝫ', 'dꝫ', 'dꝰ', 'neēt', 'wiē', 'claghē', 'mʼtē', 'vriēt', 'wꝫ', 'dꝫtu', 'vʼdraghen', 'vʼmaegt', 'dꝫ', 'mij̄', 'wʼde', 'dꝫ', 'danwʼde', 'draghē', 'dꝫ', 'comē', 'vandē', 'yerstē', 'deē', 'dandʼ', 'eyghē', 'mā', 'daʼ', 'wanē', 'quā', 'desē', 'seitmē', 'totē', 'dorꝑ', 'ōnere', 'dʼ', 'weʼlt', 'mē', 'dꝫ', 'vergᵃme', 'wāt', 'mertē', 'dīc', 'daʼ', 'sij̄', 'maʼ', 'vʼre', 'eē', 'ꝑsemeer', 'entē', 'liedē', 'thaʼe', 'sondʼ', 'ondʼ', 'sij̄', 'waʼ', 'dusētvout', 'claertē', 'vā', 'dē', 'tʼre', 'dīc', 'liedē', 'dꝫ', 'wīnē', 'en̄', 'maectʼ', 'waēt', 'dꝫ', 'eyghij̄', 'comē', 'vādē', 'quadē', 'caȳ', 'vʼmorde', 'abʼlle', 'en̄', 'vʼdoēt', 'sij̄', 'nꝫ', 'waʼ', 'rededenē', 'wāt', 'ōs', 'fij̄', 'dꝫ', 'dꝫ', 'sij̄', 'vʼdrāc', 'ī', 'mʼ', 'dꝫ', 'fenij̄', 'dꝫ', 'caȳ', 'dꝫs', 'anschij̄', 'meneghē', 'vā', 'hʼten', 'waēt', 'dꝫ', 'vādē', 'quadē', 'cā', 'wāt', 'sij̄', 'vadʼ', 'dꝫ', 'dꝫ', 'eyghē', 'vā', 'hē', 'wāt', 'hē', 'vadʼs', 'mesquā', 'diʼe', 'vītmē', 'dꝫ', 'rā', 'wīt', 'dʼ', 'vādē', 'edelē', 'quā', 'eyghē', 'vʼnā', 'erē', 'en̄', 'hē', 'mertē', 'dꝫ', 'vʼtelt', 'dꝫ', 'vā', 'onrechtʼ', 'eē', 'pʼnce', 'dꝫ', 'mē', 'mē', 'vʼdoemen', 'en̄', 'vʼcopē', 'ōme', 'dꝫ', 'mē', 'eyghē', 'en̄', 'dꝫ', 'mē', 'noemē', 'natuʼe', 'harē', 'rechtē', 'mʼ', 'auōtuʼe', 'en̄', 'meneghē', 'vromē', 'en̄', 'tonnʼen', 'hē', 'ō', 'dꝫ', 'eē', 'tondʼ', 'en̄', 'andʼ', 'wetē', 'sinē', 'mīt', 'weʼlt', 'tsinē', 'diēste', 'mē', 'dꝫ', 'sij̄', 'mʼ', 'wʼt', 'dꝫ', 'vʼsmaet', 'en̄', 'vā', 'niemē', 'wiē', 'daʼ', 'dogꝫ', 'en̄', 'vā', 'wꝫ', 'lāde', 'dꝫti', 'quā', 'dꝫs', 'diē', 'erē', 'dandʼ', 'vʼcocht', 'mē', 'sulkē', 'mā', 'niemē', 'gerouē', 'mēsche', 'proeftmē', 'sīne', 'ōs', 'sij̄', 'en̄', 'ōs', 'dꝫmē', 'wedʼ', 'ōne', 'ghenē', 'wedʼ', 'daʼ', 'ōs', 'ōs', 'daʼ', 'īne', 'legghē', 'ī', 'sinē', 'smakē', 'dā', 'kīne', 'waʼ', 'mij̄', 'vroedē', 'mʼ', 'vīdē', 'dꝫtu', 'hʼ', 'uʼwōnē', 'mīne', 'dꝫs', 'dʼ', 'zielē', 'en̄', 'mꝫ', 'sondē', 'daʼ', 'en̄', 'waē', 'ōmaer', 'dꝫ', 'ōs', 'brīghē', 'daʼ', 'mīne', 'nꝫ', 'haʼ', 'mꝫ', 'sinē', 'māne', 'mꝫtē', 'lesē', 'dꝫ', 'latē', 'bliuē', 'en̄', 'zieʼ', 'nꝫ', 'lʼrē', 'doē', 'hē', 'becliuē', 'minē', 'selē', 'wriuē', 'moghē', 'gheē', 'vā', 'keytiuē', 'daʼ', 'ō', 'ōliuē', 'ickʼ', 'lerē', 'hebbē', 'ondʼlinghe', 'dīghe', 'antwʼt', 'ōtsprīghe', 'mij̄', 'hʼte', ...
# ['lāge', 'staē', 'cranckē', 'vā', 'eerē', 'scalkē', 'connē', 'en̄', 'en̄', 'mertē', 'sprekē', 'ondʼ', 'wanē', 'sprekē', 'cōpaen', 'hebbē', 'vʼstaē', 'vʼmochte', 'dē', 'hemelscē', 'en̄', 'doē', 'begā', 'bouē', 'mā', 'mij̄', 'vāden', 'en̄', 'hē', 'dē', 'en̄', 'dʼ', 'en̄', 'heerē', 'en̄', 'gheuē', 'eenē', 'en̄', 'willē', 'wanē', 'en̄', 'en̄', 'clymmē', 'en̄', 'en̄', 'bidʼ', 'zōnen', 'ghetonē', 'en̄', 'droegē', 'ouʼ', 'wʼt', 'en̄', 'en̄', 'en̄', 'gheē', 'daermē', 'hē', 'en̄', 'gewagē', 'sneuē', 'en̄', 'ouʼ', 'vʼsmale', 'sinē', 'heʼe', 'doemē', 'qᵃde', 'en̄', 'hʼte', 'vʼbrant', 'en̄', 'vʼsmoort', 'en̄', 'meerdʼ', 'rechtē', 'tʼ', 'hellē', 'alsmē', 'en̄', 'ēmer', 'ghebondē', 'en̄', 'en̄', 'onuʼzien', 'vandē', 'en̄', 'vʼteert', 'en̄', 'en̄', 'en̄', 'mertē', 'en̄', 'sōdē', 'nꝫ', 'sondaeʼ', 'tormēt', 'en̄', 'hē', 'tellēne', 'ōmaer', 'en̄', 'wrakē', 'mertē', 'mē', 'en̄', 'en̄', 'makē', 'dē', 'en̄', 'comē', 'en̄', 'dʼ', 'dā', 'clappē', 'vʼstaet', 'gegrōden', 'willē', 'eenē', 'dōmē', 'ionctē', 'en̄', 'bezichtē', 'en̄', 'en̄', 'mertē', 'en̄', 'vʼgheten', 'hē', 'gheldē', 'en̄', 'nēmeer', 'en̄', 'hīne', 'kiekē', 'en̄', 'mīne', 'mīne', 'tormēt', 'mīne', 'proeftmē', 'en̄', 'en̄', 'hʼ', 'mīne', 'volghē', 'indʼ', 'mīne', 'mochtē', 'bringē', 'indʼ', 'mīne', 'en̄', 'mīne', 'verblindē', 'indʼ', 'dʼ', 'mʼ', 'gheenē', 'ghenē', 'nēmermeer', 'vriendē', 'mīne', 'wāt', 'en̄', 'mīne', 'dandʼ.', 'wʼ', 'en̄', 'mīne', 'en̄', 'hebbē', 'en̄', 'datmē', 'dʼ', 'mīnen', 'en̄', 'en̄', 'en̄', 'en̄', 'en̄', 'mīne', 'nēmermeer', 'werdē', 'vā', 'moetē', 'mīne', 'en̄', 'nēmermeer', 'bescreuē', 'hʼten', 'tsamē', 'cōnen', 'mīnē', 'planē', 'mertē', 'heʼe', 'en̄', 'en̄', 'en̄', 'mīnē', 'vʼplecht', 'en̄', 'ghescouwē', 'reyndʼ', 'mīnē', 'mʼ', 'makē', 'mouwē', 'en̄', 'mʼten', 'wāt', 'vʼmaecht', 'wanē', 'vʼgrame', 'dʼ', 'en̄', 'ꝑsemer', 'wīnen', 'en̄', 'dꝫ', 'eyghij̄', 'comē', 'vandē', 'quadē', 'vʼdoemt', 'fenij̄', 'aēschij̄', 'vādē', 'qᵃdē', 'cā', 'grā', 'wāt', 'mesqᵃm', 'quā', 'vʼnam', 'en̄', 'mertē', 'vʼtelt', 'vā', 'wā', 'mē', 'datmē', 'en̄', 'harē', 'rechtē', 'mʼ', 'auōtuere', 'en̄', 'en̄', 'wetē', 'sinē', 'tsinē', 'en̄', 'vā', 'en̄', 'vercoeptmē', 'sulkē', 'mā', 'hē', 'berouē', 'clēmen', 'poentē', 'mīne', 'hē', 'en̄', 'vʼstaen', 'dinē', 'quā', 'machmē', 'mʼ', 'hʼte', 'ontfaē', 'mēschelike', 'dꝰ', 'vʼstoort', 'anderē', 'en̄', 'vraghēne', 'ghʼne', 'tē', 'en̄', 'dʼ', 'dʼ', 'nēmermeer', 'vʼslijt', 'en̄', 'en̄', 'en̄', 'en̄', 'niemēs', 'mannē', 'en̄', 'en̄', 'en̄', 'redēne', 'en̄', 'en̄', 'en̄', 'stortmē', 'smēschē', 'stichtmē', 'vʼstaen', 'sondʼ', 'lietmēt', 'en̄', 'mochtmē', 'mēsche', 'costē', 'en̄', 'hʼte', 'mertē', 'vā', 'minnē', 'en̄', 'geē', 'vʼtuut', 'zwʼ', 'en̄', 'dʼ', 'vʼmijt', 'menigē', 'en̄', 'en̄', 'mettʼ', 'en̄', 'alsmē', 'dʼ', 'smēschē', 'en̄', 'en̄', 'en̄', 'en̄', 'mettē', 'en̄', 'dʼ', 'zij̄', 'en̄', 'thʼte', 'doghē', 'en̄', 'en̄', 'en̄', 'ōmaer', 'vʼmoedē', 'dʼ', 'opēbaer', 'sondē', 'spoedē', 'en̄', 'mīnen', 'watʼ', 'en̄', 'optē', 'vastē', 'minnē', 'sondʼ', 'dꝰ', 'gedaē', 'sondʼ', 'blouwē', 'en̄', 'dwaē', 'en̄', 'en̄', 'nedʼ', 'en̄', 'mertē', 'en̄', 'ih̄s', 'en̄', 'vā', 'sneuē', 'eenē', 'vandē', 'en̄', 'en̄', 'en̄', 'en̄', 'mē', 'en̄', 'en̄', 'ih̄s', 'en̄', 'dʼ', 'en̄', 'enē', 'euelē', 'vʼwoet', 'misdoē', 'dʼ', 'vrouwē', 'dꝫ', 'māsplien', 'natuerē', 'en̄', 'mānen', 'en̄', 'mīne', 'vā', 'mīnē', 'trouwē', 'en̄', 'en̄', 'vrouwē', 'vʼblint', 'vrouwē', 'harē', 'dē', 'nā', 'waendʼ', 'quā', 'mēsche', 'entē', 'mā', 'vʼnā', 'vrouwē', 'en̄', 'sondʼ', 'en̄', 'dē', 'vrouwē', 'dē', 'en̄', 'nēmeer', 'mʼtē', 'gheē', 'sprekē', 'en̄', 'en̄', 'grā', 'mesquā', 'wedʼ', 'quā', 'eē', 'mʼ', 'sʼmoen', 'dorꝑ', 'vā', 'en̄', 'minē', 'en̄', 'yserē', 'en̄', 'ontbendē', 'mīnen', 'harē', 'sondʼ', 'mij̄s', 'bekinnē', 'vʼgaen', 'verwinnē', 'andʼ', 'diemē' ...
# ['vādē', 'wapē', 'mʼten', 'crāckē', 'mij̄', 'vᵒuwē', 'vʼeere', 'saē:', 'sōdʼ', 'en̄', 'hʼen', 'dē', 'scalkē', 'ōtfaē:', 'hʼen', 'cōnē', 'dwaē:', 'en̄', 'pluckē', 'vā', 'dē', 'en̄', 'dē', 'rechtē', 'bespottē', 'en̄', 'vaē:', 'ī', 'vʼscroue', 'dꝫ', 'en̄', 'en̄', 'hē', 'dꝫ', 'dꝫ', 'ī', 'dē', 'helschē', 'swʼt', 'getᵒuwe', 'mā', 'gᵃeft', 'sondʼ', 'poēte', 'nᵗ', 'dꝫ', 'mʼtē', 'spᵉkē', 'ōdʼ', 'ōs', 'wanē', 'ōs', 'qᵃm', 'wilē', 'ōwʼt', 'en̄', 'vᵃgē', 'en̄', 'ātwʼdt', 'vā', 'dꝫ', 'ledechᵗ', 'vᵒme', 'mʼ', 'vīt', 'ī', 'dē', 'daʼ', 'ōtstect', 'dꝫ', 'tᵒege:', 'spᵉct', 'en̄', 'spᵉkē', 'cōpaē:', 'waʼ', 'hebbē', 'vʼstaē:', 'dꝫ', 'daʼ', 'vʼclaʼne', 'dinē', 'waē:', 'ī', 'bevaē:', 'dꝫ', 'nᵗ', 'ē', 'vʼmochte:', 'ē', 'nᵗ', 'ōtgaē:', 'ōtfaē:', 'vʼsochte:', 'sēde', 'dē', 'hemelschē', 'tᵃen:', 'en̄', 'moꝫ', 'minē', 'dwaē:', 'wāt', 'en̄', 'mertē', 'wʼelt', 'mā', 'vʼheffene', 'bouē', 'mā:', 'mij̄', 'vᵒuwe', 'vʼ', 'dē', 'tᵒuwe', 'en̄', 'diē', 'sij̄', 'hʼe:', 'makē', 'hʼen', 'en̄', 'geuē', 'dʼ', 'eerē', 'enē', 'en̄', 'ē', 'willē', 'nᵗ', 'dꝫ', 'wanē', 'tfenij̄', 'qᵃm:', 'toēt', 'daʼ', 'vā:', 'wāt', 'dꝫ', 'hꝫ', 'dūct', 'ouʼwaʼ:', 'sēt', 'dꝫ', 'edelhᵗ', 'vaʼ:', 'pinēne', 'ō', 'en̄', 'tᵃc', 'radē', 'hiʼ', 'daʼ:', 'en̄', 'nᵗ', 'ē', 'dē', 'hʼe:', 'edelhᵗ', 'wordē', 'swaʼ:', 'dꝫ', 'clēmene', 'ōmaer:', 'en̄', 'lāc', 'meʼe:', 'aldʼ', 'wʼelt', 'en̄', 'oechsiēs', 'oppēbaʼ:', 'vʼbānē', 'wedʼstaē', 'tē', 'mʼct', 'dʼ', 'sōnē', 'aldʼ', 'wʼelt', 'oegē', 'siʼe', 'natᶻen:', 'dꝫ', 'swʼc', 'daʼ', 'iegē', 'en̄', 'mꝫ', 'siʼe', 'dᵉft:', 'ē', 'cā', 'vrē:', 'getoegē', 'haʼ', 'scoēhᵗ', 'dꝰ', 'vʼdōkʼt', 'cᵉaturen:', 'hē', 'daʼ', 'en̄', 'edelhᵗ', 'vʼplecht:', 'laꝫ', 'geduerē:', 'dē', 'scalkē', 'suerē:', 'sīt', 'dᵒegē', 'ouʼeen:', 'dꝫ', 'en̄', 'neē:', 'en̄', 'dꝫ', 'wijshᵗ', 'en̄', 'edelhᵗ', 'daʼōme', 'wanē', 'dꝫ', 'comē', 'edelhᵗ', 'wordē', 'wāt', 'ē', 'ōtfermt', 'dīc', 'mē', 'dē', 'lāgē', 'dē', 'edelē', 'wāt', 'en̄', 'gewagē', 'vā', 'dꝫ', 'hʼen', 'geuē:', 'nᵗ', 'dā', 'bescᵉuē:', 'tᵒuwe', 'broeschʼ', 'tebrokē', 'bleuē:', 'hʼe', 'ē', 'tsinē', 'ī', 'sneuē:', 'en̄', 'lāts', 'vʼdᵉuē:', 'mertē', 'sij̄', 'hʼen', 'en̄', 'wādelbaʼ', 'ī', 'weetʼ', 'seggē', 'loeshᵗ', 'ouʼ', 'en̄', 'pij̄t', 'vʼsmale:', 'dē', 'dꝰ', 'sij̄s', 'hʼen', 'getᵉcke', 'ōs', 'doemē', 'hē', 'dꝫ', 'dē', 'dē', 'iōxstē', 'scalkē', 'ē', 'cᵉaturen:', 'qᵃde', 'dā', 'dē', 'en̄', 'ī', 'mij̄', 'ī', 'meestʼ', 'dʼ', 'natᶻen:', 'bevolē', 'mʼct', 'en̄', 'dīc', 'waʼ', 'dʼ', 'blēdʼ', 'auōtᶻen:', 'vʼkeʼt', 'vrē:', 'vʼdort:', 'dauōᶻe', 'maʼ', 'vā', 'geveysdʼ', 'spᵃkē:', 'bᶦncstu', 'ōgeloeue', 'dīc', 'en̄', 'dē', 'makē:', 'dij̄', 'hʼte', 'argʼ', 'papē', 'selēt', 'smakē:', 'wʼtstu', 'vʼbᵃnt', 'en̄', 'vʼsmoʼt:', 'ō', 'nᵗ', 'enē', 'toʼt:', 'mē', 'mꝫ', 'selkē', 'sakē:', 'nᵗ', 'genakē:', 'tʼ', 'hellē', 'waʼt:', 'en̄', 'vaʼt:', 'ī', 'sōdē:', 'mē', 'mesdaꝫ', 'spaʼt:', 'en̄', 'mē', 'ēmʼ', 'vʼswaʼt:', 'daʼ', 'ī', 'ghebondē:', 'en̄', 'dā', 'dꝫ', 'mē', 'begaʼt:', 'en̄', 'mē', 'ē', 'genē', 'stōdē:', 'dā', 'cōt', 'spaʼt:', 'onvorsiē', 'wāt', 'pādē', 'vā', 'pōdē:', 'niemē', 'ē', 'cā', 'gegᵒndē:', 'mertē', 'bekeʼt:', 'en̄', 'en̄', 'vā', 'nᵗ', 'ē', 'mij̄', 'hʼte', 'ē', 'wʼdes', 'nᵗ', 'vʼseert:', 'ī', 'negeenē', 'meʼ', 'dā', 'vteʼt:', 'en̄', 'gewīt', 'dꝫ', 'mꝫ', 'scalcheidē', 'en̄', 'mꝫ', 'ghīdʼ', 'wʼt', 'en̄', 'gehīdʼt', 'en̄', 'geōneert:', 'kīdʼ', 'enē', 'mertē', 'ē', 'nᵗ', 'dīc', 'nᵗ', 'ē', 'vᵃgē:', 'sij̄', 'sōdē', 'dꝫ', 'dē', 'sōdare', 'j̄', 'wᵃkē', 'en̄', 'plagē:', 'wāt', 'sōdare', 'ī', 'sōdē', 'ē', 'sij̄', 'tormēt', 'mꝫ', 'slagē:', 'sōdʼ', 'vʼsceet:', 'schij̄t', 'poēte', 'nᵗ', 'ē', 'wetē', 'ē', 'hʼtē', 'kīt:', 'sēdt', 'dē', 'tormēt:', 'hʼten', 'dꝫ', 'leuē', 'ōgeendt:', 'dꝫ', 'wesē', 'daʼom̄e', 'tʼ', 'hellē', 'gesēt:', 'daʼ', 'wāt', 'sij̄', 'dꝫ', 'wᵒchte:', 'dij̄', 'hʼte', 'alomtᵉnt:', 'dūct',  ...
# ['vliē', 'dʼ', 'ōtrent', 'rijchꝫ', 'vandē', 'en̄', 'leuē', 'tormēt', 'en̄', 'wᵃ', 'swᵃ', 'dʼmen', 'sondʼ', 'en̄', 'openbᵃ', 'en̄', 'hꝫ', 'dʼ', 'en̄', 'dʼ', 'ih̄s', 'en̄', 'dādi', 'en̄', 'ontfermichꝫ', 'vā', 'mildē', 'nꝫ', 'ierstē', 'dʼ', 'ōme', 'seggē', 'en̄', 'thʼte', 'vā', 'hē', 'vʼg', 'vʼlies', 'dʼ', 'nꝫ', 'dꝫ', 'willēs', 'mꝫ', 'kīne', 'en̄', 'en̄', 'vʼwo', 'dē', 'vrouwē', 'dꝫ', 'thʼte', 'dūct', 'mesdoē', 'wʼheit', 'wꝫ', 'mogēs', 'vrouwē', 'dꝫ', 'hʼe', 'scoenhꝫ', 'hē', 'natuerē', 'slechtē', 'wij̄', 'en̄', 'vʼbliden', 'vāt', 'nꝫ', 'gelidē', 'arē', 'wʼ', 'mīne', 'wordē', 'vā', 'mīnē', 'vʼwoet', 'dōmelike', 'vrouwē', 'atmē', 'trouwē', 'en̄', 'n̄', 'clagē', 'vrouwē', 'goedertierē', 'sondē', 'hē', 'vrouwē', 'vieʼ', 'harē', 'dē', 'nā', 'waendʼ', 'ōs', 'quā', 'wʼt', 'dē', 'dʼ', 'niemā', 'vʼnā', 'sprekē', 'en̄', 'en̄', 'dē', 'vrouwē', 'en̄', 'vʼgeue', 'vrouwē', 'en̄', 'dʼ', 'mꝫ', 'benā', 'tendē', 'mertē', 'dij̄', 'sprekē', 'en̄', 'dij̄', 'dꝫ', 'īt', 'tswī']
# ['wedʼ', 'wesē', 'gadʼ', 'en̄', 'sondʼ', 'mīnē', 'watʼ', 'scuwē', 'hongʼ', 'en̄', 'maertī', 'dē', 'dʼ', 'sittē', 'radē', 'rechtē', 'hē', 'dieʼ', 'hē', 'mʼ', 'hetē', 'vastē', 'mʼ', 'nꝫ', 'mīnē', 'nꝫ', 'dē', 'sondʼ', 'dꝰ', 'sondʼ', 'dē', 'eerdschē', 'en̄', 'helighē', 'hē', 'blouwē', 'en̄', 'tormenterē', 'en̄', 'ī', 'hē', 'sekʼ', 'en̄', 'nꝫ', 'euē', 'en̄', 'dʼ', 'wʼt', 'jndʼ', 'en̄', 'menighē', 'en̄', 'haʼ', 'trouwē', 'maertī', 'en̄', 'ihʼs', 'en̄', 'rechtʼ', 'scarpē', 'dornē', 'en̄', 'begheuē', 'sneuē', 'rijchᵗ']
# ['staē', 'verē', 'scalckē', 'connē', 'en̄', 'pluckē', 'gherechtē', 'vʼscroeue', 'en̄', 'mā', 'sondʼ', 'poentē', 'nꝫ', 'sprekē', 'ondʼ', 'ōs', 'tweē', 'wanē', 'en̄', 'vraeghē', 'en̄', 'vʼclaerne...', 'vʼm', 'en̄', 'minē', 'en̄', 'vʼheffen', 'dʼ', 'en̄', 'herē', 'en̄', 'dʼ', 'enē', 'en̄', 'ouʼw', 'dꝫ', 'pinē', 'om̄e', 'en̄', 'scalckē', 'woordē', 'clēmen', 'en̄', 'en̄', 'vʼbannen', 'en̄', 'wedʼ', 'sonnē', 'mꝫ', 'vʼplecht', 'dē', 'droeghē', 'ouʼeen', 'eē', 'en̄', 'dʼ', 'ōme', 'dꝫ', 'comē', 'delhᵗ', 'werdē', 'hē', 'langhē', 'weē', 'dꝫ', 'mꝫ', 'en̄', 'gewaegē', 'lantsherē', 'dā', 'eē', 'dā', 'broekē', 'hʼe', 'tsinē', 'vʼdreuen', 'herē', 'seggē', 'ouʼ', 'vʼsmaele', 'goedē', 'herē', 'doemē', 'dē', 'vʼlies', 'eē', 'beuoelē', 'vʼkeert', 'gheuinsdʼ', 'en̄', 'hʼte', 'vʼbrant', 'vʼsmoort', 'om̄e', 'nꝫ', 'en̄', 'swarē', 'hellē', 'aldʼ', 'mē', 'mesdoē', 'en̄', 'gescaedē', 'dꝫ', 'vā', 'mʼ', 'dinghē', 'dꝫ', 'mettē', 'en̄', 'alsmē', 'hʼ', 'dē', 'vʼtelt', 'gadʼ', 'elkē', 'dʼ', 'hʼte', 'ouʼ', 'en̄', 'vrouwē', 'harē', 'mʼ', 'mertē', 'mē', 'wedʼ', 'om̄e', 'oegē', 'spiē', 'dʼ', 'mʼ', 'dʼ', 'harē', 'moetē', 'en̄', 'dʼ', 'vʼtoeghen', 'ghenē', 'ouʼ', 'makē', 'hʼ', 'hē', 'vʼmoeden', 'dʼ', 'doemē', 'en̄', 'hē', 'tē', 'sondē', 'spoedē', 'gadrē', 'en̄', 'en̄', 'mīnē', 'scuwē', 'en̄', 'vʼmoede', 'mertē', 'dij̄', 'optē', 'dʼ', 'hē', 'hē', 'mʼ', 'hetē', 'sulkē', 'hʼ', 'sondʼ', 'mē', 'dē', 'ertschē', 'ōtgae', 'en̄', 'laetē', 'hē', 'blouwē', 'en̄', 'om̄e', 'hē', 'en̄', 'indʼ', 'dʼ', 'reindʼ', 'menegē', 'sinē', 'hʼ', 'mertē', 'leuē', 'mꝫ', 'vʼheuen', 'vandʼ', 'kerstenē', 'scarpē', 'dornē', 'erlikē', 'en̄', 'dꝫ', 'rijchᵗ', 'mꝫ', 'dʼ', 'hᵗ', 'menegē', 'vandē', 'vā', 'valtmē', 'en̄', 'en̄', 'clēmē', 'ioncstē', 'dagē', 'dʼ', 'sinē', 'en̄', 'dʼ', 'en̄', 'om̄e', 'hʼte', 'armē', 'en̄', 'mildē', 'weʼlt', 'en̄', 'vrouwē', 'dē', 'yerstē', 'dʼ', 'om̄e', 'en̄', 'hē', 'hʼ', 'vʼgheuen', 'mē', 'vʼlies', 'sondʼ', 'dʼ', 'om̄e', 'mertē', 'euelē', 'mꝫter', 'en̄', 'vrouwē', 'mesdoē', 'dʼ', 'wꝫ', 'mogē', 'vrouwē', 'dꝫ', 'māne', 'hʼ', 'scoenhᵗ', 'dʼ', 'hē', 'messchiē', 'en̄', 'vʼstaelde', 'hē', 'urouwē', 'natuerē', 'entʼ', 'en̄', 'dē', 'warē', 'māne', 'en̄', 'mīne', 'vā', 'mīnen', 'makē', 'vrouwē', 'en̄', 'sondʼ', 'en̄', 'en̄', 'en̄', 'mē', 'trouwē', 'vrouwē', 'dꝫ', 'mē', 'en̄', 'dā', 'claegē', 'vrouwē', 'vʼblint', 'hē', 'vrouwē', 'harē', 'dē', 'waendʼ', 'quaē', 'om̄e', 'wʼt', 'mēsche', 'vʼsoende', 'dē', 'vadʼ', 'en̄', 'dē', 'entē', 'mā', 'vʼnam', 'eē', 'bedʼuen', 'dē', 'vrouwē', 'dē', 'māne', 'vrouwē', 'en̄', 'om̄e', 'dʼ', 'quaē', 'benaē', 'thelschē', 'nēmeer', 'mertē', 'dij̄', 'sprekē', 'sprekē', 'vʼdoren', 'en̄', 'wʼt', 'dꝫ', 'vʼsworen', 'en̄', 'grā', 'vʼnaem', 'vā', 'woordē', 'wedʼ', 'quaē', 'en̄', 'mʼ', 'vʼstant', 'en̄', 'dꝫ', 'hʼte', 'dʼ', 'hʼ', 'wʼelt', 'en̄', 'dꝫ', 'en̄', 'mīne', 'vā', 'dꝫ', 'weʼlt', 'vʼdriuen', 'mē', 'min̄e', 'vā', 'vrouwē', 'makē', 'dij̄', 'sermoē', 'dorpʼ', 'vā', 'coē', 'hʼte', 'en̄', 'stekē', 'en̄', 'hoerē', 'hʼ', 'yserē', 'ontwindē', 'vʼstaen', 'om̄e', 'gewinnē', 'sondʼ', 'nꝫ', 'om̄e', 'vʼgaen', 'vʼwinnen', 'andʼ', 'mīt', 'bouē', 'dꝫ', 'mʼ', 'en̄', 'vā', 'allē', 'vʼblent', 'mij̄', 'hʼte', 'dꝫ', 'dꝫ', 'hʼ', 'stuckē', 'om̄e', 'quaē', 'en̄', 'vʼstant', 'moꝫ', 'dʼ', 'leuē', 'brekē', 'en̄', 'hʼ', 'moꝫ', 'deē', 'bitē', 'mʼ', 'en̄', 'geēs', 'vragēs', 'wʼheit', 'nꝫ', 'ēmer', 'dʼ', 'hʼten', 'en̄', 'danē', 'hʼ', 'quaemē', 'hindʼwaert', 'dē', 'reinē', 'hʼ', 'hʼ', 'en̄', 'mā', 'mā', 'ioncstē', 'woordē', 'dʼ', 'aē', 'twarē', 'dʼ', 'vadʼ', 'vʼbaerē', 'doemē', 'mꝫ', 'sinē', 'scaerē', 'vʼclaerē', 'vʼdonckert', 'purgerē', 'dē', 'sinē', 'hāde', 'en̄', 'vʼgeeft', 'en̄', 'dꝫ', 'en̄', 'smaekē', 'en̄', 'en̄', 'godhᵗ', 'niemē', '...nē', 'gegrōdē', 'vloeydē', 'en̄', 'hē', 'hē', 'clēmē', 'vandē', 'vadʼ', 'en̄', 'vandē', 'dʼ', 'martelerē', 'dʼ', 'bouē', 'i ...
# ['en̄', 'rumē', 'heerē', 'ghedoghē', 'zondʼ', 'sprekē', 'ondʼ', 'tweē', 'cōpaen', 'hebbē', 'uʼstaē', 'ontfaē', 'dē', 'hemelschē', 'zinnē', 'vʼheffene', 'bouē', 'vʼstac', 'heerē', 'gheuē', 'eenē', 'wanē', 'ōme', 'heʼe', 'wordē', 'clēmene', 'ōmaer', 'ghesindē', 'dʼ', 'sonnē', 'aldʼ', 'oghē', 'ieghē', 'en̄', 'ghetoghē', 'hē', 'en̄', 'scalkē', 'droughē', 'ouʼ', 'en̄', 'ōme', 'dij̄c', 'hē', 'en̄', 'en̄', 'brieuē', 'ghewaghē', 'dā', 'heʼen', 'ouʼ', 'en̄', 'uʼsmaele', 'dē', 'heʼen', 'treckē', 'en̄', 'vʼdoort', 'auēture', 'hʼte', 'vʼstoort', 'vʼbrant', 'en̄', 'vʼsmoort', 'dij̄', 'en̄', 'ghebondē', 'mē', 'vʼswaert', 'onuʼsien', 'wāt', 'ghegrondē', 'en̄', 'quadē', 'uʼseert', 'ghenē', 'ghebondē', 'zondē', 'plaeghē', 'wāt', 'zōdare', 'zondē', 'tormēt', 'daerōme', 'hellē', 'en̄', 'louerē', 'dropelē', 'hē', 'ōmaer', 'hē', 'mē', 'en̄', 'en̄', 'makē', 'dē', 'en̄', 'en̄', 'scrifturē', 'lekē', 'liedē', 'dij̄ghē', 'vondē', 'wanē', 'woordē', 'wortelē', 'wanē', 'vraghē', 'dōme', 'kamꝑ', 'ionxtē', 'en̄', 'berechtē', 'ōweert', 'zeluē', 'dē', 'onbesceidē', 'gheldē', 'en̄', 'en̄', 'en̄', 'wordē', 'ꝑlemēt', 'mīne', 'blēt', 'bē', 'mīne', 'mīne', 'instrumēt', 'maechdē', 'hēzeluē', 'ī', 'zij̄', 'mīnen', 'mīne', 'rijkē', 'mīne', 'wāt', 'ōme', 'mīne', 'vʼslijt', 'en̄', 'hē', 'mīne', 'ōme', 'en̄', 'en̄', 'ōme', 'mīnene', 'mā', 'ōme', 'tonghē', 'en̄', 'menighē', 'en̄', 'wilē', 'en̄', 'eerē', 'eē', 'wʼden', 'moetē', 'mīne', 'nēmermeer', 'zinnē', 'en̄', 'mē', 'bescreuē', 'hertē', 'tsamē', 'connē', 'minnē', 'trauwē', 'mīne', 'plamē', 'heʼe', 'mīnē', 'vʼplecht', 'en̄', 'minnē', 'ontrouwē', 'mouwē.', 'en̄', 'vʼmaecht', 'cōmē', 'dē', 'dorꝑ', 'willecōme', 'vʼgrame', 'hē', 'dʼ', 'waʼe', 'wīnene', 'commē', 'vā', 'dē', 'quadē', 'vʼdoemt', 'dorꝑlic', 'vādē', 'quadē', 'chā', 'grā', 'hē', 'quā', 'wāt', 'mesquā', 'quā', 'vʼtelt', 'vā', 'pᶦnche', 'wā', 'ōme', 'mē', 'eyghē', 'rechtē', 'en̄', 'menighē', 'hē', 'ōme', 'hē', 'zinē', 'en̄', 'zij̄', 'vʼsmaet', 'vā', 'en̄', 'gherouē', 'en̄', 'clemmē', 'pointē', 'en̄', 'en̄', 'en̄', 'en̄', 'tonduechdē', 'dinē', 'woordē', 'sinē', 'quā', 'mē', 'cā', 'milthedē', 'smenschē', 'mēschelijc', 'vʼstoort', 'vʼmoort', 'en̄', 'en̄', 'nēmermeer', 'vʼslijt', 'mij̄', 'en̄', 'dʼmede', 'zij̄', 'vʼwoet', 'ōme', 'smēschē', 'ōme', 'en̄', 'mē', 'prouuē', 'vā', 'dʼ', 'cōmet', 'dʼ', 'hertē', 'cōmet', 'minnē', 'andʼ', 'en̄', 'zij̄', 'en̄', 'tusschē', 'dʼ', 'en̄', 'gheloghē', 'menighē', 'brāt', 'vʼboden', 'en̄', 'vʼsmoorde', 'en̄', 'wāt', 'en̄', 'en̄', 'dē', 'uʼtelt', 'oeghē', 'oeghē', 'oeghē', 'desē', 'en̄', 'ghenē', 'waʼe', 'ōmaer', 'vermoedē', 'en̄', 'gadʼ', 'minnē', 'watʼ', 'scuwē', 'en̄', 'dij̄', 'rechtē', 'hē', 'hē', 'vastē', 'zij̄', 'zōdʼ', 'mīnē', 'dē', 'bouē', 'ghedaē', 'zij̄', 'hē', 'bleuwē', 'en̄', 'hē', 'en̄', 'euē', 'en̄', 'en̄', 'en̄', 'zij̄', 'en̄', 'doornē', 'sneuē', 'tormēt', 'menighē', 'vā', 'en̄', 'en̄', 'clēmene', 'en̄', 'ihʼs', 'vā', 'en̄', 'mildē', 'en̄', 'dē', 'vrauwē', 'ōme', 'en̄', 'segghē', 'en̄', 'vergheuē', 'yemēde', 'dē', 'draghē', 'en̄', 'zeluē', 'vʼwoet', 'dē', 'vrauwē', 'vrouwē', 'mānē', 'naturē', 'dē', 'en̄', 'en̄', 'mannē', 'en̄', 'mīne', 'vā', 'mīnē', 'vʼwoet', 'trauwē', 'vrauwē', 'en̄', 'mannē', 'dā', 'claghē', 'vrouwē', 'uʼblint', 'zondē', 'vrauwē', 'haerē', 'dē', 'quā', 'ōme', 'themelschē', 'dē', 'vā', 'daē', 'vʼnam', 'tonghē', 'en̄', 'vrouwē', 'dē', 'mānē', 'en̄', 'quā', 'bē', 'primꝰ', 'secundꝰ', 'dij̄', 'gheē', 'sprekē', 'en̄', 'dē', 'en̄', 'bē', 'grā', 'wordē', 'woordē', 'bē', 'vʼstant', 'en̄', 'vā', 'dij̄', 'dij̄', 'dorꝑ', 'vā', 'minē', 'vʼstaen', 'minnē', 'zondʼ', 'bekinnē', 'ōme', 'vʼgaen', 'gheē', 'vʼwinnē', 'bouē', 'mīne', 'allē', 'hertē', 'zij̄', 'hauwē', 'en̄', 'vʼstant', 'vʼbant', 'ghenietē', 'dē', 'gheēs', 'vraghēs', 'en̄', ...
# ['en̄', 'en̄', 'nᵗ', 'en̄', 'selēne', 'wriuē', 'hēnes', 'ō', 'ōtliuē', 'en̄', 'daʼ', 'kīnēne', 'hē', 'en̄', 'kīnēne', 'gehīge', 'waerhᵗ', 'en̄', 'thʼte', 'bevīge', 'wāt', 'tusschē', 'ōs', 'mertē', 'bouē', 'en̄', 'haʼre', 'vollē', 'en̄', 'ī', 'dij̄re', 'spʼct', 'beestē', 'dē', 'mēsche', 'ō', 'dꝫ', 'ī', 'vā', 'doekē', 'mettē', 'wisē', 'cloekē', 'tgoꝫ', 'soudʼ', 'vloekē', 'nᵗ', 'vʼgramē', 'ī', 'mij̄', 'dʼ', 'hoegʼ', 'namē', 'vʼre', 'nᵗ', 'dīge', 'quamē', 'cōstē', 'godhᵗ', 'geramē', 'maʼ', 'minē', 'crankē', '+minē', 'lamē', 'ghewōdt', 'sondē', 'mertē', 'mʼc', 'ī', 'wesē', 'sij̄', 'goꝫ', 'mīne', 'daʼ', 'mēne', 'kīt', 'sij̄', 'sij̄', 'en̄', 'en̄', 'bouē', 'en̄', 'thᵒen', 'bouē', 'en̄', 'hʼke', 'en̄', 'binnē', 'dīc', 'stʼke', 'seggē', 'ōs', 'ē', 'ī', 'butē', 'binnē', 'ī', 'watʼ', 'ī', 'ī', 'sondʼ', 'ēmer', 'niē', 'ondʼ', 'allē', 'dīc', 'mogēdelec', 'en̄', 'jegē', 'vʼscheet', 'butē', 'mꝫ', 'siʼe', 'wʼe', 'sij̄', 'mꝫ', 'vʼuult', 'steꝫ', 'wiēt', 'vʼlast', 'sondʼ', 'vā', 'rustē', 'iagē', 'butē', 'en̄', 'ē', 'niewerīc', 'sij̄', 'dagē', 'wāt', 'sōdʼ', 'vᵃgē', 'weʼt', 'en̄', 'nᵗ', 'binnē', 'en̄', 'iegē', 'ōgerast', 'enē', 'en̄', 'heileghē', 'en̄', 'gᵒt', 'ē', 'noemē', 'cleenē', 'dattʼ', 'iemē', 'enē', 'seggē', 'enē', 'vʼvʼescht', 'en̄', 'sij̄', 'dē', 'helschē', 'tēpeest', 'ongewōnen', 'en̄', 'en̄', 'voʼ', 'vā', 'gewōnen', 'beghī', 'leerē', 'dē', 'dorē', 'ōttoe', 'dij̄', 'orē', 'en̄', 'storē', 'wāt', 'siē', 'cōstē', 'ō', 'gewī', 'ghegᵒndē', 'meʼ', 'mī', 'achtʼ', 'dē', 'tē', 'en̄', 'vā', 'ōtbonde', 'haʼre', 'ī', 'warē', 'en̄', 'niemē', 'hē', 'smakē', 'wāt', 'mogē', 'dʼ', 'dīc', 'genakē', 'en̄', 'cōnen', 'tʼ', 'dīc', 'gerakē', 'hꝫ', 'ōtseit', 'moꝫ', 'wilē', 'daʼōme', 'wakē', 'cōst', 'sakē', 'vīt', 'mē', 'ī', 'mēschelecheit', 'beidē', 'vīt', 'ī', 'godhᵗ', 'dʼe', 'ꝑsone', 'leerē', 'thᵒen', 'stʼren', 'en̄', 'sōne', 'keerē', 'en̄', 'nochtā', 'sij̄', 'rustē', 'hē', 'nᵗ', 'ē', 'porrē', 'vʼre', 'dās', 'schʼen', 'mīdʼen', 'meerē', 'sij̄s', 'doꝫ', 'dīc', 'generē', 'rijchᵗ', 'niemē', 'vʼteren', 'dīc', 'vʼuult', 'ē', 'maʼ', 'sij̄re', 'keʼt', 'sij̄', 'en̄', 'nᵗ', 'dꝫ', 'hē', 'kerē', 'noꝫ', 'ōvʼde', 'hē', 'ōledechede', 'dꝫ', 'dē', 'gisterē', 'ōse', 'leuē', 'en̄', 'daʼ', 'gedreuē', 'maʼ', 'mē', 'vā', 'vīt', 'bescʼuē', 'woʼt', 'hedē', 'bleuē', 'ōme', 'gāc', 'ē', 'cleuē', 'ē', 'vʼheuen', 'sij̄', 'beneuē', 'en̄', 'bescreuē', 'en̄', 'gemāc', 'wʼelt', 'strāc', 'mertē', 'ē', 'en̄', 'euē', 'euē', 'thᵒene', 'dᵃecht', 'nᵗ', 'cᵒene', 'maʼ', 'eerē', 'loēne', 'nᵗ', 'boēne', 'dꝫ', 'ātwʼdt', 'en̄', 'vā', 'ī', 'en̄', 'tʼcke', 'en̄', 'mīne', 'wʼt', 'bouē', 'gewīne', 'en̄', 'daʼ', 'coningīne', 'ātwʼdt', 'ē', 'vʼboʼt', 'vadʼ', 'en̄', 'en̄', 'dꝫ', 'maʼ', 'claʼ', 'dꝫ', 'hꝫ', 'dē', 'ōtfinc', 'ōsen', 'en̄', 'en̄', 'en̄', 'dꝫ', 'diēne', 'ōtfinc', 'en̄', 'ōme', 'dꝫ', 'gestʼcke', 'ōse', 'dīc', 'en̄', 'clarē', 'en̄', 'wiē', 'dinē', 'en̄', 'vā', 'sōdē', 'vʼen', 'thʼte', 'sondʼ', 'wīc', 'vā', 'en̄', 'ē', 'nᵗ', 'dꝫ', 'gīc', 'mertē', 'vā', 'lufʼe', 'dʼ', 'houʼdē', 'en̄', 'hʼe', 'gᵒt', 'dꝫ', 'īgele', 'ōtgoudē', 'mꝫ', 'hē', 'warē', 'vtē', 'kʼe', 'en̄', 'vielē', 'ī', 'dꝫ', 'dꝫ', 'geboꝫ', 'en̄', 'besittē', 'ēmʼmeere', 'en̄', 'nuttē', 'bʼet', 'sōdʼ', 'wedʼ', 'en̄', 'totʼ', 'mēschᵗ', 'comē', 'spʼkēde', 'ī', 'tserpēt', 'en̄', 'tōser', 'ōvʼmē', 'vordʼs', 'doē', 'vʼdoemē', 'en̄', 'swaʼlike', 'gescēt', 'sij̄', 'sōdʼlīge', 'beroemē', 'algadʼ', 'nᵗ', 'soemē', 'dꝫ', 'vʼblēt', 'vtē', 'droemē', 'dꝫ', 'ē', 'soudē', 'wʼdē', 'bekēt', 'daʼ', 'otwēt', 'dē', 'mā', 'vʼraden', 'en̄', 'gᵒt', 'en̄', 'hē', 'staē', 'ī', 'stadē', 'dꝫ', 'siʼe', 'genadē', 'mariē', 'dꝫ', 'ōtboet', 'mꝫ', 'hē', 'wʼt', 'sondʼ', 'vā', 'en̄', 'sondʼ', 'noꝫ', 'soegē', 'en̄', 'badē', 'dīc', 'en̄', 'houdē', 'ī', 'harē', 'nᵗ', 'ē', 'vʼdᵒet', 'en̄', 'ī', 'dʼ', 'magꝫ', 'en̄ ...
# ['rumē', 'dē', 'heerē', 'en̄', 'dꝫtie', 'swʼt', 'sondʼ', 'ondʼ', 'tweē', 'en̄', 'vragē', 'hebbē', 'verstaē', 'vʼclaren', 'vʼmochte', 'dē', 'hemelschē', 'en̄', 'en̄', 'doē', 'dē', 'dʼ', 'makē', 'heerē', 'en̄', 'gheuē', 'eerē', 'enē', 'en̄', 'wanē', 'en̄', 'en̄', 'dꝫ', 'clemmē', 'ōmaer', 'en̄', 'dꝫ', 'vʼbannen', 'wedʼ', 'staē', 'sonnē', 'yegē', 'cā', 'hʼ', 'dꝫ', 'scalkē', 'suerē', 'droeghē', 'ouʼeē', 'en̄', 'ōme', 'dʼ', 'wanē', 'dꝫ', 'hʼ', 'dʼ', 'dē', 'weē', 'edelē', 'en̄', 'gewagē', 'vā', 'lansheerē', 'eē', 'dā', 'heʼe', 'tsinē', 'sneuē', 'en̄', 'vʼdreuen', 'heerē', 'en̄', 'wandelē', 'seggē', 'ouʼ', 'vʼsmale', 'edelē', 'heerē', 'doemē', 'eē', 'dē', 'vʼlies', 'curē', 'dʼ', 'dij̄', 'vʼbrant', 'en̄', 'vʼsmort', 'ō', 'sulkē', 'dꝫ', 'dꝫ', 'mꝫ', 'en̄', 'vroedē', 'dieꝑ', 'indʼ', 'hellē', 'alsmē', 'gheē', 'en̄', 'beswʼt', 'en̄', 'mē', 'en̄', 'mesuʼt', 'ghenē', 'besnidē', 'doepē', 'proeuē', 'diē', 'tidē', 'hʼ', 'en̄', 'doorborē', 'en̄', 'hellē', 'tidē', 'dʼ', 'verblidē', 'benediē', 'stridē', 'dʼ', 'vā', 'vandē', 'reinē', 'en̄', 'mā', 'yegē', 'ionxstē', 'werdē', 'geuarē', 'sagē', 'twarē', 'sparē', 'vadʼ', 'carē', 'hē', 'openbarē', 'doemē', 'sinē', 'scarē', 'vʼclarē', 'verdōckert', 'warē', 'dꝫ', 'en̄', 'becāde', 'vʼgeeft', 'en̄', 'euelē', 'dꝫ', 'en̄', 'smakē', 'en̄', 'zidē', 'sacramentē', 'en̄', 'vā', 'harē', 'hē', 'mē', 'mē', 'clemmē', 'en̄', 'gauē', 'vandē', 'dꝫ', 'dʼ', 'dʼ', 'bouē', 'hogē', 'en̄', 'wʼt', 'en̄', 'en̄', 'euē', 'en̄', 'versciedē', 'vʼstant', 'dobbelē', 'gegrondē', 'dā', 'menegē', 'prophetē', 'en̄', 'coningin̄e', 'gewinnē', 'wʼt', 'weluarē', 'apostelē', 'doē', 'sondʼ', 'vʼclaren', 'vʼswarē', 'sinē', 'sondʼ', 'sparē', 'begheuē', 'vʼstant', 'mē', 'eē', 'en̄', 'wedʼ', 'en̄', 'wʼt', 'dꝫmē', 'indē', 'en̄', 'dʼna', 'dʼ', 'dʼ', 'mꝫ', 'dꝫ', 'scuwē']
# ['wʼ', 'mʼ', 'dē', 'rikē', 'ghenē', 'genē', 'nēmermeʼe', 'dꝫ', 'dꝫ', 'diʼe', 'alleē', 'dʼ', 'vriēde', 'mōt', 'mē', 'hʼ', 'doē', 'en̄', 'nꝫ', 'scendē', 'dandʼ', 'mīne', 'ōbehoet', 'wāt', 'en̄', 'riddʼscap', 'uʼwoet', 'en̄', 'dē', 'wāt', 'riddʼ', 'nꝫ', 'uʼslijt', 'en̄', 'dꝫ', 'dandʼ', 'wʼ', 'en̄', 'hē', 'indē', 'hē', 'dorstē', 'heuꝫ', 'ondʼsceet', 'vā', 'hē', 'eʼe', 'en̄', 'dʼ', 'wʼlt', 'eʼe', 'hebbē', 'latē', 'dꝫ', 'dꝫ', 'en̄', 'dogꝫ', 'dꝫmē', 'ondʼ', 'dʼ', 'gloriē', 'mꝫ', 'ōme', 'wāt', 'smeltē', 'pᶦsen', 'eē', 'dʼ', 'hʼte', 'mꝫ', 'ōme', 'wꝰ', 'reynē', 'en̄', 'hʼtē', 'loddʼs', 'en̄', 'wilē', 'en̄', 'dꝫ', 'weldoē', 'hebbē', 'en̄', 'nuttē', 'dꝫs', 'eē', 'mʼ', 'mīne', 'eē', 'dꝫ', 'nēmermeere', 'wʼdē', 'mēt', 'hʼ', 'geuē', 'mīne', 'vā', 'dʼ', 'scuwē', 'dʼ', 'eʼen', 'wāt', 'salamoē', 'heuꝫ', 'bescreuē', 'nꝫ', 'dʼde', 'mīne', 'dē', 'natuerē', 'ōtbeit', 'dꝫs', 'hʼ', 'scamelhᵗ', 'en̄', 'mē', 'dogꝫ', 'heuꝫ', 'diemē', 'tʼ', 'wāt', 'taldʼ', 'vʼblijt', 'hʼ', 'hʼ', 'nēmermeʼe', 'aldꝰ', 'vʼslijt', 'en̄', 'geē', 'alsmē', 'vīt', 'hʼtē', 'tsamē', 'bīt', 'eenē', 'reynē', 'dꝫte', 'mīne', 'cōt', 'dꝫ', 'menegē', 'kīt', 'dꝫti', 'hē', 'uʼspanenē', 'cōnē', 'mīnē', 'nꝫ', 'eē', 'twīt', 'wādel', 'sij̄', 'wīt', 'rollē', 'waē', 'mʼ', 'vīt', 'mīners', 'swanē', 'vrouwē', 'en̄', 'joffrouwē', 'dꝫsi', 'mꝫ', 'mīnē', 'uʼplecht', 'dꝫ', 'wʼlt', 'iegē', 'dʼ', 'reindʼ', 'mīnē', 'en̄', 'volgē', 'dʼ', 'en̄', 'mij̄', 'aē', 'zeʼe', 'waē', 'bedouwē', 'achtʼ', 'makē', 'mouwē', 'gevᵃgꝫ', 'antwʼde', 'en̄', 'vʼdraget', 'mʼtē', 'vʼdragen', 'waēdi', 'dꝫ', 'behagꝫ', 'dꝫtu', 'dꝰ', 'geiagꝫ', 'neēt', 'wiē', 'clagē', 'mʼtē', 'vriēt', 'wꝫ', 'geclagꝫ', 'vragꝫ', 'dꝫtu', 'vʼdragꝫ', 'vʼdragen', 'wāt', 'dꝫ', 'mij̄', 'wʼde', 'dꝫ', 'danwʼde', 'wagē', 'dꝫ', 'comē', 'vandē', 'ierstē', 'dandʼ', 'dʼ', 'eygē', 'wanē', 'quā', 'desē', 'seitmē', 'totē', 'dorꝑ', 'onneʼe', 'dʼ', 'wʼlt', 'mē', 'dꝫ', 'dꝫ', 'vʼgrame', 'wāt', 'ōtame', 'mertē', 'dʼ', 'en̄', 'vʼges', 'heuꝫ', 'eē', 'ꝑsemʼ', 'en̄', 'dē', 'ondʼ', 'zij̄', 'vandē', 'dꝫ', 'wīne', 'en̄', 'en̄', 'waēt', 'eygij̄', 'comē', 'vāden', 'vʼmorde', 'en̄', 'diē', 'vʼdoēt', 'mʼtijn', 'redenē', 'wāt', 'dꝫ', 'dꝫ', 'geslachtē', 'vʼdranc', 'mʼ', 'dꝫ', 'dꝫ', 'scij̄', 'menegē', 'hʼten', 'waēt', 'dꝫ', 'vandē', 'sij̄', 'vadʼ', 'wꝰ', 'dꝫ', 'nꝫ', 'dꝫ', 'eygē', 'hē', 'quā', 'wāt', 'mesqᵃm', 'diʼe', 'dꝫtie', 'dʼ', 'vandē', 'edelē', 'quā', 'eygē', 'vʼnā', 'dꝫ', 'en̄', 'hē', 'mertē', 'dꝫ', 'eygēdom', 'eē', 'pᶦnse', 'wā', 'dꝫmē', 'dedemē', 'en̄', 'vʼcopē', 'dꝫs', 'dꝫmē', 'eygē', 'en̄', 'noemē', 'natuʼe', 'harē', 'mʼ', 'auētuʼe', 'en̄', 'tonneʼen', 'dꝫ', 'eē', 'tʼ', 'nedʼ', 'menschᵗ', 'dꝫter', 'en̄', 'en̄', 'sinē', 'hʼ', 'ō', 'sturtmē', 'smēschē', 'hʼ', 'ō', 'stichtmē', 'mꝫtʼ', 'meneghē', 'uʼstaen', 'dꝫ', 'wʼ', 'sondʼ', 'dꝫtu', 'lietmēt', 'gaē', 'īt', 'gemeē', 'en̄', 'hē', 'ōtfaen', 'dꝰ', 'dꝰ', 'dwaē', 'en̄', 'clarē', 'vandē', 'milthᵗ', 'heuꝫ', 'hʼ', 'gedaē', 'vrechᵗ', 'vlaē', 'proeuē', 'wīners', 'vandē', 'pondē', 'eē', 'dīc', 'cōt', 'eē', 'mēsche', 'wʼt', 'gewōt', 'dʼ', 'ogē', 'hertē', 'grōt', 'costē', 'eē', 'pōt', 'en̄', 'wʼde', 'desʼ', 'stōt', 'eē', 'mij̄', 'hʼte', 'dij̄', 'mōt', 'wāt', 'nꝫ', 'wijshᵗ', 'dꝫ', 'redēne', 'mertē', 'eē', 'vrēt', 'eē', 'aldʼhande', 'cōt', 'vā', 'mīnē', 'en̄', 'dꝫ', 'dorpʼ', 'hulpē', 'mīt', 'ouʼ', 'dā', 'hē', 'dʼ', 'hʼtē', 'entʼ', 'dꝫ', 'hʼ', 'en̄', 'eē', 'swʼ', 'en̄', 'eē', 'zwʼ', 'en̄', 'dʼtoe', 'eē', 'tusschē', 'thʼte', 'en̄', 'thʼte', 'dē', 'ogē', 'vʼwijt', 'mij̄s', 'nꝫ', 'vʼmijt', 'emmʼ', 'opē', 'elkʼ', 'sondē', 'teneghʼ', 'dʼ', 'dꝫ', 'minē', 'wapē', 'vriēdelijc', 'menegē', 'pāt', 'en̄', 'wapē', 'dꝫ', 'natuʼe', 'wʼ', 'uʼbodē', 'en̄', 'en̄', 'menschē', 'geē', 'lichtʼ', 'wʼic', 'dā', 'algadʼ', 'mē', 'mꝫtʼ', 'hāt', 'en̄', 'vʼsmorde', 'sulkē', 'ondʼ', 'dꝫ', 'natuʼe', 'tthʼte', 'waē', 'conīghinne', 'dꝫ', 'wāt', ' ...
#     Expanded Word  Count Witness
# 0             en̄    289       A
# 1              dʼ     77       A
# 2             hē     71       A
# 3             vā     66       A
# 4             dē     59       A
# 5             mē     30       A
# 6              mʼ     25       A
# 7            ōme     24       A
# 8           sondʼ     23       A
# 9            wāt     21       A
# 10            en̄      3     Ant
# 11             dʼ      1     Ant
# 12         mertē      1     Ant
# 13             dꝫ      1     Ant
# 14        gelogē      1     Ant
# 15           negʼ      1     Ant
# 16        menegē      1     Ant
# 17     metterhāt      1     Ant
# 18           lkē      1     Ant
# 19           īne      1     Ant
# 20            en̄    224       B
# 21            dē     47       B
# 22            hē     46       B
# 23          mīne     37       B
# 24             dʼ     36       B
# 25          sondʼ     34       B
# 26            vā     22       B
# 27             mʼ     20       B
# 28          weʼlt     18       B
# 29           ōme     18       B
# 30            en̄     87      BR
# 31             dꝫ     66      BR
# 32             dʼ     25      BR
# 33             nꝫ     21      BR
# 34           sij̄     13      BR
# 35          mīne     13      BR
# 36             hʼ     13      BR
# 37             mʼ     12      BR
# 38            hē     12      BR
# 39          thʼte     11      BR
# 40            en̄    283       C
# 41            vā      5       C
# 42     ghegrondē      2       C
# 43          zinē      1       C
# 44          lamē      1       C
# 45          minē      1       C
# 46         smakē      1       C
# 47       ghenakē      1       C
# 48             ī      1       C
# 49         stedē      1       C
# 50            en̄     12       D
# 51            vā      7       D
# 52            dē      5       D
# 53           geē      3       D
# 54        vrouwē      3       D
# 55           mij̄      3       D
# 56        nyemāt      3       D
# 57            ōs      3       D
# 58         datmē      3       D
# 59         hertē      2       D
# 60            en̄     32      D2
# 61            vā      7      D2
# 62        vrouwē      4      D2
# 63           mij̄      4      D2
# 64            hē      4      D2
# 65           wedʼ      3      D2
# 66          sondʼ      3      D2
# 67     nēmermeer      2      D2
# 68         eyndē      1      D2
# 69             dʼ      1      D2
# 70            en̄     40       E
# 71             dꝫ     39       E
# 72           sij̄     15       E
# 73            daʼ     15       E
# 74            hē     14       E
# 75            vā     14       E
# 76          mīne     10       E
# 77            mē     10       E
# 78           wāt      9       E
# 79            eē      8       E
# 80            en̄    204       F
# 81             dʼ     27       F
# 82          mīne     22       F
# 83            vā     21       F
# 84            dē     11       F
# 85             mʼ     11       F
# 86            hē     10       F
# 87          sondʼ     10       F
# 88         mertē      8       F
# 89          eenē      8       F
# 90            en̄    341       G
# 91             dꝫ    217       G
# 92             ī    111       G
# 93             ē    109       G
# 94            dē    103       G
# 95             nᵗ     82       G
# 96            vā     72       G
# 97           sij̄     70       G
# 98            hē     63       G
# 99            daʼ     61       G
# 100           en̄     17      Ge
# 101            dʼ      7      Ge
# 102       vrouwē      7      Ge
# 103            dꝫ      4      Ge
# 104           dē      4      Ge
# 105           vā      3      Ge
# 106            nꝫ      3      Ge
# 107           hē      3      Ge
# 108         thʼte      2      Ge
# 109            mꝫ      2      Ge
# 110           en̄     12       K
# 111           hē      4       K
# 112         sondʼ      3       K
# 113           dē      3       K
# 114            nꝫ      3       K
# 115        mīnē      2       K
# 116       maertī      2       K
# 117            dʼ      2       K
# 118            mʼ      2       K
# 119          wedʼ      1       K
# 120           en̄     80       L
# 121            dʼ     35       L
# 122            dꝫ     22       L
# 123           hē     17       L
# 124           dē     15       L
# 125           vā     13       L
# 126            hʼ     13       L
# 127          om̄e     12       L
# 128       vrouwē     11       L
# 129           mē      8       L
# 130           en̄    128       O
# 131           vā     28       O
# 132           hē     25       O
# 133           dē     24       O
# 134         mīne     24       O
# 135          ōme     18       O
# 136          zij̄     16       O
# 137           mē     11       O
# 138            dʼ      9       O
# 139        minnē      9       O
# 140           en̄    102       W
# 141            ī     27       W
# 142            dꝫ     22       W
# 143            ē     20       W
# 144           vā     17       W
# 145            nᵗ     15       W
# 146           hē     14       W
# 147          sij̄     14       W
# 148           dē     13       W
# 149           daʼ     11       W
# 150           en̄     35       Y
# 151            dʼ     10       Y
# 152            dꝫ     10       Y
# 153           dē      5       Y
# 154        heerē      4       Y
# 155           mē      4       Y
# 156         sondʼ      3       Y
# 157            hʼ      3       Y
# 158           vā      3       Y
# 159           eē      3       Y
# 160           en̄     83       Z
# 161            dꝫ     53       Z
# 162            dʼ     31       Z
# 163            hʼ     28       Z
# 164           eē     23       Z
# 165            nꝫ     18       Z
# 166           dē     17       Z
# 167           hē     17       Z
# 168            mꝫ     16       Z
# 169          sij̄     16       Z
