# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Step 1: Read the TSV files
file_path_full = '/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/A_output_corrected kopie.tsv'  # Update this with the path to your full TSV file
file_path_ids = '/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/A_M1_1_001.tsv'  # Update this with the path to your line IDs TSV file

data_full = pd.read_csv(file_path_full, delimiter='\t', header=0)
line_ids = pd.read_csv(file_path_ids, delimiter='\t', header=None, names=['line_id'])
shuffled_line_ids = line_ids.sample(frac=1, random_state=42).reset_index(drop=True)
# Step 2: Merge the line IDs with the full data
merged_data = pd.merge(shuffled_line_ids, data_full, on='line_id', how='left')



# Step 4: Split into 80% train and 20% combined validation + test
train_data, temp_data = train_test_split(shuffled_data, test_size=0.2, random_state=42, shuffle=False)

# Step 5: Split the combined 20% into 10% validation and 10% test
val_data, test_data = train_test_split(temp_data, test_size=0.5, random_state=42, shuffle=False)

# Step 6: Drop the 'line_id' column
train_data.to_csv('/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/train_data.tsv', sep='\t', index=False, header=False)
val_data.to_csv('/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/val_data.tsv', sep='\t', index=False, header=False)
test_data.to_csv('/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/test_data.tsv', sep='\t', index=False, header=False)

# Print the lengths of each set to verify the splits
print(f"Length of train_data: {len(train_data)}")
print(f"Length of val_data: {len(val_data)}")
print(f"Length of test_data: {len(test_data)}")

# Optionally, save the splits to new TSV files
# Out:
# Length of train_data: 36816
# Length of val_data: 4602
# Length of test_data: 4602

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Step 1: Read the TSV files
file_path_full = '/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/A_output_corrected kopie.tsv'
file_path_ids = '/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/A_M1_1_001.tsv'

data_full = pd.read_csv(file_path_full, delimiter='\t', header=0)
line_ids = pd.read_csv(file_path_ids, delimiter='\t', header=None, names=['line_id'])

# Step 2: Remove duplicate line IDs to get unique line IDs
unique_line_ids = line_ids.drop_duplicates().reset_index(drop=True)

# Step 3: Shuffle the unique line IDs
shuffled_unique_line_ids = unique_line_ids.sample(frac=1, random_state=42).reset_index(drop=True)

# Step 4: Expand shuffled unique line IDs back to the full length with empty lines preserved
expanded_line_ids = []
for line_id in shuffled_unique_line_ids['line_id']:
    expanded_line_ids.extend(line_ids[line_ids['line_id'] == line_id].values.tolist())

# Convert the expanded list back to a DataFrame
shuffled_line_ids_expanded = pd.DataFrame(expanded_line_ids, columns=['line_id'])

# Step 5: Merge the expanded shuffled line IDs with the full data
shuffled_data = pd.merge(shuffled_line_ids_expanded, data_full, on='line_id', how='left')

# Step 6: Split into 80% train and 20% combined validation + test
train_data, temp_data = train_test_split(shuffled_data, test_size=0.2, random_state=42, shuffle=False)

# Step 7: Split the combined 20% into 10% validation and 10% test
val_data, test_data = train_test_split(temp_data, test_size=0.5, random_state=42, shuffle=False)

# Step 8: Save the splits to new TSV files, preserving the empty lines
train_data.to_csv('/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/train_data.tsv', sep='\t', index=False, header=False)
val_data.to_csv('/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/val_data.tsv', sep='\t', index=False, header=False)
test_data.to_csv('/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/test_data.tsv', sep='\t', index=False, header=False)

# Print the lengths of each set to verify the splits
print(f"Length of train_data: {len(train_data)}")
print(f"Length of val_data: {len(val_data)}")
print(f"Length of test_data: {len(test_data)}")
# Out:
# Length of train_data: 36816
# Length of val_data: 4602
# Length of test_data: 4602

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Step 1: Read the TSV files
file_path_full = '/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/A_output_corrected kopie.tsv'
file_path_ids = '/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/A_M1_1_001.tsv'

data_full = pd.read_csv(file_path_full, delimiter='\t', header=0)
line_ids = pd.read_csv(file_path_ids, delimiter='\t', header=None, names=['line_id'])

# Step 2: Remove duplicate line IDs to get unique line IDs
unique_line_ids = line_ids.drop_duplicates().reset_index(drop=True)

# Step 3: Shuffle the unique line IDs
shuffled_unique_line_ids = unique_line_ids.sample(frac=1, random_state=42).reset_index(drop=True)

# Step 4: Expand shuffled unique line IDs back to the full length with empty lines preserved
expanded_line_ids = []
for line_id in shuffled_unique_line_ids['line_id']:
    expanded_line_ids.extend(line_ids[line_ids['line_id'] == line_id].values.tolist())

# Convert the expanded list back to a DataFrame
shuffled_line_ids_expanded = pd.DataFrame(expanded_line_ids, columns=['line_id'])

# Step 5: Merge the expanded shuffled line IDs with the full data
shuffled_data = pd.merge(shuffled_line_ids_expanded, data_full, on='line_id', how='left')

# Step 6: Split into 80% train and 20% combined validation + test
train_data, temp_data = train_test_split(shuffled_data, test_size=0.2, random_state=42, shuffle=False)

# Step 7: Split the combined 20% into 10% validation and 10% test
val_data, test_data = train_test_split(temp_data, test_size=0.5, random_state=42, shuffle=False)

# Step 8: Save the splits to new TSV files, preserving the empty lines
train_data.to_csv('/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/train_data.tsv', sep='\t', index=False, header=False)
val_data.to_csv('/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/val_data.tsv', sep='\t', index=False, header=False)
test_data.to_csv('/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/test_data.tsv', sep='\t', index=False, header=False)

# Print the lengths of each set to verify the splits
print(f"Length of train_data: {len(train_data)}")
print(f"Length of val_data: {len(val_data)}")
print(f"Length of test_data: {len(test_data)}")
# Out:
# Length of train_data: 36816
# Length of val_data: 4602
# Length of test_data: 4602

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Step 1: Read the TSV files
file_path_full = '/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/A_output_corrected kopie.tsv'
file_path_ids = '/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/A_M1_1_001.tsv'

data_full = pd.read_csv(file_path_full, delimiter='\t', header=0)
line_ids = pd.read_csv(file_path_ids, delimiter='\t', header=None, names=['line_id'])

# Step 2: Extract unique line IDs and shuffle them
unique_line_ids = line_ids.drop_duplicates()
shuffled_unique_line_ids = unique_line_ids.sample(frac=1, random_state=42).reset_index(drop=True)

# Step 3: Expand shuffled unique line IDs back to the full length
expanded_shuffled_line_ids = pd.DataFrame(columns=['line_id'])
for line_id in shuffled_unique_line_ids['line_id']:
    expanded_shuffled_line_ids = pd.concat([expanded_shuffled_line_ids, line_ids[line_ids['line_id'] == line_id]])

expanded_shuffled_line_ids.reset_index(drop=True, inplace=True)

# Step 4: Merge the expanded shuffled line IDs with the full data
shuffled_data = pd.merge(expanded_shuffled_line_ids, data_full, on='line_id', how='left')

# Step 5: Split into 80% train and 20% combined validation + test
train_data, temp_data = train_test_split(shuffled_data, test_size=0.2, random_state=42, shuffle=False)

# Step 6: Split the combined 20% into 10% validation and 10% test
val_data, test_data = train_test_split(temp_data, test_size=0.5, random_state=42, shuffle=False)

# Step 7: Save the splits to new TSV files, preserving the empty lines
train_data.to_csv('/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/train_data.tsv', sep='\t', index=False, header=False)
val_data.to_csv('/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/val_data.tsv', sep='\t', index=False, header=False)
test_data.to_csv('/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/test_data.tsv', sep='\t', index=False, header=False)

# Print the lengths of each set to verify the splits
print(f"Length of train_data: {len(train_data)}")
print(f"Length of val_data: {len(val_data)}")
print(f"Length of test_data: {len(test_data)}")
# Out:
# Length of train_data: 36816
# Length of val_data: 4602
# Length of test_data: 4602

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Step 1: Read the TSV file
file_path = '/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/A_M1_1_001.tsv'

data_full = pd.read_csv(file_path, delimiter='\t', header=None, names=['line_id', 'token', 'lemma', 'pos'])
line_ids = data_full[['line_id']].dropna()

# Step 2: Extract unique line IDs and shuffle them
unique_line_ids = line_ids.drop_duplicates().reset_index(drop=True)
shuffled_unique_line_ids = unique_line_ids.sample(frac=1, random_state=42).reset_index(drop=True)

# Step 3: Expand shuffled unique line IDs back to the full length with empty lines preserved
expanded_shuffled_line_ids = []
for line_id in shuffled_unique_line_ids['line_id']:
    expanded_shuffled_line_ids.extend(line_ids[line_ids['line_id'] == line_id].values.tolist())
    expanded_shuffled_line_ids.append([None])  # Add None to preserve empty lines

expanded_shuffled_line_ids_df = pd.DataFrame(expanded_shuffled_line_ids, columns=['line_id'])

# Merge with the full data
shuffled_data = pd.merge(expanded_shuffled_line_ids_df, data_full, on='line_id', how='left')

# Step 4: Split into 80% train and 20% combined validation + test
train_data, temp_data = train_test_split(shuffled_data, test_size=0.2, random_state=42, shuffle=False)

# Step 5: Split the combined 20% into 10% validation and 10% test
val_data, test_data = train_test_split(temp_data, test_size=0.5, random_state=42, shuffle=False)

# Step 6: Save the splits to new TSV files, preserving the empty lines
train_data.to_csv('/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/train_data.tsv', sep='\t', index=False, header=False)
val_data.to_csv('/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/val_data.tsv', sep='\t', index=False, header=False)
test_data.to_csv('/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/test_data.tsv', sep='\t', index=False, header=False)

# Print the lengths of each set to verify the splits
print(f"Length of train_data: {len(train_data)}")
print(f"Length of val_data: {len(val_data)}")
print(f"Length of test_data: {len(test_data)}")
# Out:
# Length of train_data: 38228
# Length of val_data: 4779
# Length of test_data: 4779

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Step 1: Read the TSV files
file_path_full = '/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/A_output_corrected kopie.tsv'
file_path_ids = '/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/A_M1_1_001.tsv'

line_ids = pd.read_csv(file_path_ids, delimiter='\t', header=None, names=['line_id'])
data_full = pd.read_csv(file_path_full, delimiter='\t', header=0)

# Step 2: Extract unique line IDs and shuffle them
unique_line_ids = line_ids.drop_duplicates().reset_index(drop=True)
shuffled_unique_line_ids = unique_line_ids.sample(frac=1, random_state=42).reset_index(drop=True)

# Step 3: Expand shuffled unique line IDs back to the full length with empty lines preserved
expanded_shuffled_line_ids = []
for line_id in shuffled_unique_line_ids['line_id']:
    expanded_shuffled_line_ids.extend(line_ids[line_ids['line_id'] == line_id].values.tolist())
    expanded_shuffled_line_ids.append([None])  # Add None to preserve empty lines

expanded_shuffled_line_ids_df = pd.DataFrame(expanded_shuffled_line_ids, columns=['line_id'])

# Merge with the full data
shuffled_data = pd.merge(expanded_shuffled_line_ids_df, data_full, on='line_id', how='left')

# Step 4: Split into 80% train and 20% combined validation + test
train_data, temp_data = train_test_split(shuffled_data, test_size=0.2, random_state=42, shuffle=False)

# Step 5: Split the combined 20% into 10% validation and 10% test
val_data, test_data = train_test_split(temp_data, test_size=0.5, random_state=42, shuffle=False)

# Step 6: Save the splits to new TSV files, preserving the empty lines
train_data.to_csv('/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/train_data.tsv', sep='\t', index=False, header=False)
val_data.to_csv('/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/val_data.tsv', sep='\t', index=False, header=False)
test_data.to_csv('/Users/sofiemoors/Library/CloudStorage/OneDrive-UniversiteitAntwerpen/Documenten/Vormvast/collate_constraints/data/tsv_files_corrected/test_data.tsv', sep='\t', index=False, header=False)

# Print the lengths of each set to verify the splits
print(f"Length of train_data: {len(train_data)}")
print(f"Length of val_data: {len(val_data)}")
print(f"Length of test_data: {len(test_data)}")
# Out:
# Length of train_data: 2528995
# Length of val_data: 316124
# Length of test_data: 316125
